# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
# Separate out the features.
x = train.iloc[:, 2:].values
# Separate out the target.
y = train.iloc[:, 1].values

# %%
x.shape
# Out:
# (200000, 200)

# %%
from sklearn.decomposition import PCA
pca = PCA(50)
projected = pca.fit_transform(x)

# %%
plt.scatter(projected[:, 0], projected[:, 1],
           c=y, edgecolor='none', alpha=0.5,
           cmap=plt.cm.get_cmap('copper', 10))
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar();

# %%
pca = PCA().fit(x)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
import lightgbm as lgb
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score, roc_curve

# %%
features = [c for c in train.columns if c not in ['ID_code', 'target']]
target = train['target']

# %% [markdown]
# # LGB

# %%
features = [c for c in train.columns if c not in ['ID_code', 'target']]
target = train['target']

# %%
mean_list = train[features].mean().values
std_list = train[features].std().values

# %%
train = (train[features] - mean_list) / std_list
test = (test[features] - mean_list) / std_list

# %%
from sklearn.decomposition import PCA
pca = PCA(100)
projected = pca.fit_transform(train.values)

# %%
train = projected

# %%
for i in range(50):
    train['new_' + str(i)] = projected[:, i]

# %%
# https://www.kaggle.com/fayzur/customer-transaction-prediction-strong-baseline
# Thanks fayzur. Nice Parameter 
param = {
        'num_leaves': 10,
        'max_bin': 119,
        'min_data_in_leaf': 11,
        'learning_rate': 0.02,
        'min_sum_hessian_in_leaf': 0.00245,
        'bagging_fraction': 1.0, 
        'bagging_freq': 5, 
        'feature_fraction': 0.05,
        'lambda_l1': 4.972,
        'lambda_l2': 2.276,
        'min_gain_to_split': 0.65,
        'max_depth': -1,
        'save_binary': True,
        'seed': 1337,
        'feature_fraction_seed': 1337,
        'bagging_seed': 1337,
        'drop_seed': 1337,
        'data_random_seed': 1337,
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': 1,
        'metric': 'auc',
        'is_unbalance': True,
        'boost_from_average': False,
    }

# %%
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

oof_lgb = np.zeros(len(train))
predictions_lgb = np.zeros(len(test))
feature_importance = pd.DataFrame()

train_columns = [c for c in train.columns if c not in ['ID_code', 'target']]

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, target.values)):    
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(train.iloc[trn_idx][train_columns], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train.iloc[val_idx][train_columns], label=target.iloc[val_idx])

    num_round = 60000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=3000, early_stopping_rounds = 200)
    oof_lgb[val_idx] = clf.predict(train.iloc[val_idx][train_columns], num_iteration=clf.best_iteration)
    
#     predictions_lgb += clf.predict(test[train_columns], num_iteration=clf.best_iteration) / folds.n_splits
    
    fold_importance = pd.DataFrame()
    fold_importance["Feature"] = train_columns
    fold_importance["importance"] = clf.feature_importance()
    fold_importance["fold"] = fold_ + 1
    feature_importance = pd.concat([feature_importance, fold_importance], axis=0)
    
    print("CV score: {:<8.5f}".format(roc_auc_score(target.values[val_idx], oof_lgb[val_idx])))
    
print("CV score: {:<8.5f}".format(roc_auc_score(target.values, oof_lgb)))
# Out:
# fold n°0
# Training until validation scores don't improve for 200 rounds.
# [3000]	training's auc: 0.927339	valid_1's auc: 0.895367
# Early stopping, best iteration is:
# [5308]	training's auc: 0.946229	valid_1's auc: 0.896835
# CV score: 0.89684
# fold n°1
# Training until validation scores don't improve for 200 rounds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-aaebecf27fec> in <module>
#      13
#      14     num_round = 60000
# ---> 15     clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=3000, early_stopping_rounds = 200)
#      16     oof_lgb[val_idx] = clf.predict(train.iloc[val_idx][train_columns], num_iteration=clf.best_iteration)
#      17
#
# c:\python\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     221             if is_valid_contain_train:
#     222                 evaluation_result_list.extend(booster.eval_train(feval))
# --> 223             evaluation_result_list.extend(booster.eval_valid(feval))
#     224         try:
#     225             for cb in callbacks_after_iter:
#
# c:\python\lib\site-packages\lightgbm\basic.py in eval_valid(self, feval)
#    1933             List with evaluation results.
#    1934         """
# -> 1935         return [item for i in range_(1, self.__num_dataset)
#    1936                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1937
#
# c:\python\lib\site-packages\lightgbm\basic.py in <listcomp>(.0)
#    1934         """
#    1935         return [item for i in range_(1, self.__num_dataset)
# -> 1936                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1937
#    1938     def save_model(self, filename, num_iteration=None, start_iteration=0):
#
# c:\python\lib\site-packages\lightgbm\basic.py in __inner_eval(self, data_name, data_idx, feval)
#    2320                 ctypes.c_int(data_idx),
#    2321                 ctypes.byref(tmp_out_len),
# -> 2322                 result.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#    2323             if tmp_out_len.value != self.__num_inner_eval:
#    2324                 raise ValueError("Wrong length of eval results")
#
# KeyboardInterrupt:

# %%
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

oof_lgb = np.zeros(len(train))
predictions_lgb = np.zeros(len(test))
feature_importance = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, target.values)):    
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(train[trn_idx], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train[val_idx], label=target.iloc[val_idx])

    num_round = 60000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=3000, early_stopping_rounds = 200)
    oof_lgb[val_idx] = clf.predict(train[val_idx], num_iteration=clf.best_iteration)
    
#     predictions_lgb += clf.predict(test[train_columns], num_iteration=clf.best_iteration) / folds.n_splits
    
    print("CV score: {:<8.5f}".format(roc_auc_score(target.values[val_idx], oof_lgb[val_idx])))
    
print("CV score: {:<8.5f}".format(roc_auc_score(target.values, oof_lgb)))
# Out:
# fold n°0
# Training until validation scores don't improve for 200 rounds.
# [3000]	training's auc: 0.926293	valid_1's auc: 0.8848
# [6000]	training's auc: 0.947987	valid_1's auc: 0.888484
# Early stopping, best iteration is:
# [5845]	training's auc: 0.947037	valid_1's auc: 0.888512
# CV score: 0.88851
# fold n°1
# Training until validation scores don't improve for 200 rounds.
# [3000]	training's auc: 0.926307	valid_1's auc: 0.885652
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-5c4da9f875fe> in <module>
#      11
#      12     num_round = 60000
# ---> 13     clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=3000, early_stopping_rounds = 200)
#      14     oof_lgb[val_idx] = clf.predict(train[val_idx], num_iteration=clf.best_iteration)
#      15
#
# c:\python\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     221             if is_valid_contain_train:
#     222                 evaluation_result_list.extend(booster.eval_train(feval))
# --> 223             evaluation_result_list.extend(booster.eval_valid(feval))
#     224         try:
#     225             for cb in callbacks_after_iter:
#
# c:\python\lib\site-packages\lightgbm\basic.py in eval_valid(self, feval)
#    1933             List with evaluation results.
#    1934         """
# -> 1935         return [item for i in range_(1, self.__num_dataset)
#    1936                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1937
#
# c:\python\lib\site-packages\lightgbm\basic.py in <listcomp>(.0)
#    1934         """
#    1935         return [item for i in range_(1, self.__num_dataset)
# -> 1936                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    1937
#    1938     def save_model(self, filename, num_iteration=None, start_iteration=0):
#
# c:\python\lib\site-packages\lightgbm\basic.py in __inner_eval(self, data_name, data_idx, feval)
#    2320                 ctypes.c_int(data_idx),
#    2321                 ctypes.byref(tmp_out_len),
# -> 2322                 result.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#    2323             if tmp_out_len.value != self.__num_inner_eval:
#    2324                 raise ValueError("Wrong length of eval results")
#
# KeyboardInterrupt:

# %%
cols = (feature_importance[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False).index)
best_features = feature_importance.loc[feature_importance.Feature.isin(cols)]

plt.figure(figsize=(14,26))
sns.barplot(x="importance", y="Feature", data=best_features.sort_values(by="importance",ascending=False))
plt.title('LightGBM Features (averaged over folds)')
plt.tight_layout()

# %%
cols[:200]
# Out:
# Index(['var_108', 'var_6', 'var_34', 'var_53', 'var_133', 'var_12', 'var_78',
#        'var_81', 'var_191', 'var_9',
#        ...
#        'var_64', 'var_25', 'var_3', 'new_28', 'new_37', 'var_59', 'var_69',
#        'var_143', 'var_68', 'new_4'],
#       dtype='object', name='Feature', length=200)
