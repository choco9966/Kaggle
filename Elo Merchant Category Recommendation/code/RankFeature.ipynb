# %%
import gc
from datetime import datetime, timedelta,date
import warnings
import itertools
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.random_projection import GaussianRandomProjection
from sklearn.random_projection import SparseRandomProjection,johnson_lindenstrauss_min_dim
from sklearn.decomposition import PCA, FastICA,NMF,LatentDirichletAllocation,IncrementalPCA,MiniBatchSparsePCA
from sklearn.decomposition import TruncatedSVD,FactorAnalysis,KernelPCA

import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, log_loss
from sklearn.model_selection import StratifiedKFold, KFold

from scipy.stats import ks_2samp
import tqdm

#settings
warnings.filterwarnings('ignore')
np.random.seed(2018)
pd.set_option("display.max_columns", None)

# %%
def get_prefix(group_col, target_col, prefix=None):
    if isinstance(group_col, list) is True:
        g = '_'.join(group_col)
    else:
        g = group_col
    if isinstance(target_col, list) is True:
        t = '_'.join(target_col)
    else:
        t = target_col
    if prefix is not None:
        return prefix + '_' + g + '_' + t
    return g + '_' + t
    
def groupby_helper(df, group_col, target_col, agg_method, prefix_param=None):
    try:
        prefix = get_prefix(group_col, target_col, prefix_param)
        print(group_col, target_col, agg_method)
        group_df = df.groupby(group_col)[target_col].agg(agg_method)
        group_df.columns = ['{}_{}'.format(prefix, m) for m in agg_method]
    except BaseException as e:
        print(e)
    return group_df.reset_index()

# %%
def get_hist_default_prorcessing(df):
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    df['category_3'] = df['category_3'].map({'A':0, 'B':1, 'C':2}) 
    df['month_diff'] = ((datetime(2019,1,20) - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']
    df['reference_date'] = (df['year']+(df['month'] - df['month_lag'])//12)*100 + (((df['month'] - df['month_lag'])%12) + 1)*1
    return df

# %%
def create_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
historical_trans_df = pd.read_csv('input/historical_transactions.csv')
new_merchant_trans_df = pd.read_csv('input/new_merchant_transactions.csv')
merchant_df = pd.read_csv('input/merchants.csv')[['merchant_id','merchant_group_id','category_4','active_months_lag3','active_months_lag6','active_months_lag12']]

# %%
historical_trans_df = historical_trans_df.sort_values('purchase_date')

# %%
historical_trans_df = get_hist_default_prorcessing(historical_trans_df)

# %%
train_df = pd.read_csv('input/train.csv')
test_df = pd.read_csv('input/test.csv')

# %%
monthlag_last = groupby_helper(historical_trans_df,['card_id'],'month_lag',['max'])
historical_trans_df = historical_trans_df.merge(monthlag_last, on='card_id', how='left')
historical_trans_df.loc[historical_trans_df['month_lag']==historical_trans_df['card_id_month_lag_max'],'month_lag_reference'] = 1


monthlag_last = groupby_helper(historical_trans_df.loc[historical_trans_df['month_lag_reference']!=0],['card_id'],'month_lag',['max'],'before')
historical_trans_df = historical_trans_df.merge(monthlag_last, on='card_id', how='left')
historical_trans_df.loc[historical_trans_df['month_lag']==historical_trans_df['before_card_id_month_lag_max'],'month_lag_reference'] = 1
historical_trans_df['month_lag_reference'].fillna(0, inplace=True)

group_df = groupby_helper(historical_trans_df.loc[historical_trans_df['month_lag_reference']==0],['card_id'],'month_lag',['nunique'])
historical_trans_df = historical_trans_df.merge(group_df,on='card_id',how='left')
historical_trans_df.loc[historical_trans_df['card_id_month_lag_nunique'].isnull(),'card_id_month_lag_nunique'] = 0
card_id_month_lag_nunique = groupby_helper(historical_trans_df,['card_id'],'card_id_month_lag_nunique',['max'])
# Out:
# ['card_id'] month_lag ['max']
# ['card_id'] month_lag ['max']
# ['card_id'] month_lag ['nunique']
# ['card_id'] card_id_month_lag_nunique ['max']

# %%
hist_trans_df_lastmonth = historical_trans_df.loc[historical_trans_df['month_lag_reference']==1]
hist_trans_df_before_lastmonth = historical_trans_df.loc[historical_trans_df['month_lag_reference']==0]

# %%
train_df['convert_target'] = np.power(2,train_df['target'])-9.999999992192566e-11
all_df = pd.concat([train_df,test_df])
all_df['feature123'] = all_df['feature_1'].astype(str) +'_'+all_df['feature_2'].astype(str)+'_'+all_df['feature_3'].astype(str)
all_df['feature123'] = pd.factorize(all_df['feature123'])[0]

# %%
reference_max = groupby_helper(historical_trans_df,['card_id'],'reference_date','max')
all_df = all_df.merge(reference_max, on='card_id', how='left')
# Out:
# ['card_id'] reference_date max

# %% [markdown]
# ### Subsector

# %%
subsector_lastmonth = groupby_helper(hist_trans_df_lastmonth,['card_id','subsector_id'],'month_lag','size')
subsector_lastmonth_pivot = subsector_lastmonth.pivot('card_id','subsector_id','month_lag').reset_index()
subsector_lastmonth_pivot.columns = ['card_id']+['lastmonth_subsector_id_{}'.format(col) for col in subsector_lastmonth_pivot.columns if col != 'card_id']
subsector_lastmonth_pivot.fillna(0, inplace=True)
# Out:
# ['card_id', 'subsector_id'] month_lag size

# %%
subsector_before_lastmonth = groupby_helper(hist_trans_df_before_lastmonth,['card_id','subsector_id'],'month_lag','size')
subsector_before_lastmonth_pivot = subsector_before_lastmonth.pivot('card_id','subsector_id','month_lag').reset_index()
subsector_before_lastmonth_pivot.columns = ['card_id']+['before_lastmonth_subsector_id_{}'.format(col) for col in subsector_before_lastmonth_pivot.columns if col != 'card_id']
subsector_before_lastmonth_pivot.fillna(0, inplace=True)
# Out:
# ['card_id', 'subsector_id'] month_lag size

# %%
subsector_id = subsector_lastmonth_pivot.merge(subsector_before_lastmonth_pivot,on='card_id',how='left')

# %%
train_df = all_df.loc[all_df['target'].notnull()]

# %%
subsector_id = subsector_id.merge(train_df[['card_id','target']],on='card_id',how='left')

# %%
subsector_id_train = subsector_id.loc[subsector_id['target'].notnull()]
subsector_id_test = subsector_id.loc[subsector_id['target'].isnull()]

# %%
subsector_id_train['outliers'] = 0
subsector_id_train.loc[subsector_id_train['target'] < -30, 'outliers'] = 1

train_columns = [c for c in subsector_id_train.columns if c not in ['card_id', 'first_active_month','target','outliers','rank']]
train_columns
# Out:
# ['lastmonth_subsector_id_-1',
#  'lastmonth_subsector_id_1',
#  'lastmonth_subsector_id_2',
#  'lastmonth_subsector_id_3',
#  'lastmonth_subsector_id_4',
#  'lastmonth_subsector_id_5',
#  'lastmonth_subsector_id_7',
#  'lastmonth_subsector_id_8',
#  'lastmonth_subsector_id_9',
#  'lastmonth_subsector_id_10',
#  'lastmonth_subsector_id_11',
#  'lastmonth_subsector_id_12',
#  'lastmonth_subsector_id_13',
#  'lastmonth_subsector_id_14',
#  'lastmonth_subsector_id_15',
#  'lastmonth_subsector_id_16',
#  'lastmonth_subsector_id_17',
#  'lastmonth_subsector_id_18',
#  'lastmonth_subsector_id_19',
#  'lastmonth_subsector_id_20',
#  'lastmonth_subsector_id_21',
#  'lastmonth_subsector_id_22',
#  'lastmonth_subsector_id_23',
#  'lastmonth_subsector_id_24',
#  'lastmonth_subsector_id_25',
#  'lastmonth_subsector_id_26',
#  'lastmonth_subsector_id_27',
#  'lastmonth_subsector_id_28',
#  'lastmonth_subsector_id_29',
#  'lastmonth_subsector_id_30',
#  'lastmonth_subsector_id_31',
#  'lastmonth_subsector_id_32',
#  'lastmonth_subsector_id_33',
#  'lastmonth_subsector_id_34',
#  'lastmonth_subsector_id_35',
#  'lastmonth_subsector_id_36',
#  'lastmonth_subsector_id_37',
#  'lastmonth_subsector_id_38',
#  'lastmonth_subsector_id_39',
#  'lastmonth_subsector_id_40',
#  'lastmonth_subsector_id_41',
#  'before_lastmonth_subsector_id_-1',
#  'before_lastmonth_subsector_id_1',
#  'before_lastmonth_subsector_id_2',
#  'before_lastmonth_subsector_id_3',
#  'before_lastmonth_subsector_id_4',
#  'before_lastmonth_subsector_id_5',
#  'before_lastmonth_subsector_id_7',
#  'before_lastmonth_subsector_id_8',
#  'before_lastmonth_subsector_id_9',
#  'before_lastmonth_subsector_id_10',
#  'before_lastmonth_subsector_id_11',
#  'before_lastmonth_subsector_id_12',
#  'before_lastmonth_subsector_id_13',
#  'before_lastmonth_subsector_id_14',
#  'before_lastmonth_subsector_id_15',
#  'before_lastmonth_subsector_id_16',
#  'before_lastmonth_subsector_id_17',
#  'before_lastmonth_subsector_id_18',
#  'before_lastmonth_subsector_id_19',
#  'before_lastmonth_subsector_id_20',
#  'before_lastmonth_subsector_id_21',
#  'before_lastmonth_subsector_id_22',
#  'before_lastmonth_subsector_id_23',
#  'before_lastmonth_subsector_id_24',
#  'before_lastmonth_subsector_id_25',
#  'before_lastmonth_subsector_id_26',
#  'before_lastmonth_subsector_id_27',
#  'before_lastmonth_subsector_id_28',
#  'before_lastmonth_subsector_id_29',
#  'before_lastmonth_subsector_id_30',
#  'before_lastmonth_subsector_id_31',
#  'before_lastmonth_subsector_id_32',
#  'before_lastmonth_subsector_id_33',
#  'before_lastmonth_subsector_id_34',
#  'before_lastmonth_subsector_id_35',
#  'before_lastmonth_subsector_id_36',
#  'before_lastmonth_subsector_id_37',
#  'before_lastmonth_subsector_id_38',
#  'before_lastmonth_subsector_id_39',
#  'before_lastmonth_subsector_id_40',
#  'before_lastmonth_subsector_id_41']

# %%
train = subsector_id_train.copy()
target = train['target']
del train['target']

# %%
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.015,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 24,
         "seed": 6}

#prepare fit model with cross-validation
np.random.seed(2019)


feature_importance_df = pd.DataFrame()
folds = KFold(n_splits=9, shuffle=True, random_state=4950)
oof = np.zeros(len(train))
predictions = np.zeros(len(test_df))
cv_score_list = []
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, train['outliers'].values)):
    strLog = "fold {}".format(fold_+1)
    print(strLog)
    trn_data = lgb.Dataset(train.iloc[trn_idx][train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 100)
    oof[val_idx] = clf.predict(train.iloc[val_idx][train_columns], num_iteration=clf.best_iteration)
    
    cv_score = np.sqrt(mean_squared_error(oof[val_idx], target.iloc[val_idx]))
    cv_score_list.append(cv_score)
    #feature importance
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    #predictions
    predictions += clf.predict(subsector_id_test[train_columns], num_iteration=clf.best_iteration) / folds.n_splits

cv_score = np.sqrt(mean_squared_error(oof, target))
print(cv_score)
print(cv_score_list)
print(np.std(cv_score_list))
withoutoutlier_predictions = predictions.copy()
# Out:
# fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.83882	valid_1's rmse: 3.66375
# [200]	training's rmse: 3.81774	valid_1's rmse: 3.66304
# Early stopping, best iteration is:
# [161]	training's rmse: 3.82507	valid_1's rmse: 3.66287
# fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81069	valid_1's rmse: 3.89955
# [200]	training's rmse: 3.79035	valid_1's rmse: 3.89892
# [300]	training's rmse: 3.77432	valid_1's rmse: 3.8998
# Early stopping, best iteration is:
# [202]	training's rmse: 3.78999	valid_1's rmse: 3.89888
# fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.80891	valid_1's rmse: 3.90747
# [200]	training's rmse: 3.78867	valid_1's rmse: 3.90583
# [300]	training's rmse: 3.77278	valid_1's rmse: 3.90567
# Early stopping, best iteration is:
# [276]	training's rmse: 3.77621	valid_1's rmse: 3.90558
# fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.82973	valid_1's rmse: 3.74739
# [200]	training's rmse: 3.80938	valid_1's rmse: 3.74606
# [300]	training's rmse: 3.79411	valid_1's rmse: 3.74567
# Early stopping, best iteration is:
# [284]	training's rmse: 3.79624	valid_1's rmse: 3.74548
# fold 5
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81166	valid_1's rmse: 3.88945
# [200]	training's rmse: 3.79125	valid_1's rmse: 3.88721
# [300]	training's rmse: 3.77558	valid_1's rmse: 3.88679
# Early stopping, best iteration is:
# [279]	training's rmse: 3.77857	valid_1's rmse: 3.88627
# fold 6
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81812	valid_1's rmse: 3.84192
# [200]	training's rmse: 3.79722	valid_1's rmse: 3.83992
# [300]	training's rmse: 3.7812	valid_1's rmse: 3.839
# [400]	training's rmse: 3.76854	valid_1's rmse: 3.83893
# Early stopping, best iteration is:
# [381]	training's rmse: 3.77083	valid_1's rmse: 3.83868
# fold 7
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.83481	valid_1's rmse: 3.70507
# [200]	training's rmse: 3.81416	valid_1's rmse: 3.70261
# [300]	training's rmse: 3.79886	valid_1's rmse: 3.70178
# [400]	training's rmse: 3.78558	valid_1's rmse: 3.7016
# [500]	training's rmse: 3.77444	valid_1's rmse: 3.70147
# Early stopping, best iteration is:
# [454]	training's rmse: 3.77941	valid_1's rmse: 3.70117
# fold 8
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.79286	valid_1's rmse: 4.04316
# [200]	training's rmse: 3.7729	valid_1's rmse: 4.03983
# [300]	training's rmse: 3.75777	valid_1's rmse: 4.03816
# [400]	training's rmse: 3.74508	valid_1's rmse: 4.0378
# [500]	training's rmse: 3.7338	valid_1's rmse: 4.0378
# Early stopping, best iteration is:
# [470]	training's rmse: 3.73708	valid_1's rmse: 4.03761
# fold 9
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81614	valid_1's rmse: 3.85305
# [200]	training's rmse: 3.79579	valid_1's rmse: 3.85173
# [300]	training's rmse: 3.7801	valid_1's rmse: 3.85204
# Early stopping, best iteration is:
# [235]	training's rmse: 3.79013	valid_1's rmse: 3.85147
# 3.8380156597850132
# [3.662869246111782, 3.8988836696675597, 3.905578296505156, 3.7454771544262795, 3.8862689322204376, 3.838683791924768, 3.701165093088047, 4.037607308778356, 3.8514664983415114]
# 0.10982900898400745

# %%
subsector_train_pred = pd.concat([pd.DataFrame(train['card_id']).reset_index(drop=True),pd.DataFrame(oof, columns=['subsector_id_pred'])],axis=1)
subsector_test_pred = pd.concat([pd.DataFrame(test_df['card_id']).reset_index(drop=True),pd.DataFrame(predictions, columns=['subsector_id_pred'])],axis=1)
subsector_pred = pd.concat([subsector_train_pred,subsector_test_pred])
subsector_pred.to_csv('subsector_id_pred.csv',index=False)

# %% [markdown]
# ### MerchantCategoryId

# %%
subsector_lastmonth = groupby_helper(hist_trans_df_lastmonth,['card_id','merchant_category_id'],'month_lag','size')
subsector_lastmonth_pivot = subsector_lastmonth.pivot('card_id','merchant_category_id','month_lag').reset_index()
subsector_lastmonth_pivot.columns = ['card_id']+['lastmonth_merchant_category_id_{}'.format(col) for col in subsector_lastmonth_pivot.columns if col != 'card_id']
subsector_lastmonth_pivot.fillna(0, inplace=True)
# Out:
# ['card_id', 'merchant_category_id'] month_lag size

# %%
subsector_before_lastmonth = groupby_helper(hist_trans_df_before_lastmonth,['card_id','merchant_category_id'],'month_lag','size')
subsector_before_lastmonth_pivot = subsector_before_lastmonth.pivot('card_id','merchant_category_id','month_lag').reset_index()
subsector_before_lastmonth_pivot.columns = ['card_id']+['before_lastmonth_merchant_category_id_{}'.format(col) for col in subsector_before_lastmonth_pivot.columns if col != 'card_id']
subsector_before_lastmonth_pivot.fillna(0, inplace=True)
# Out:
# ['card_id', 'merchant_category_id'] month_lag size

# %%
subsector_id = subsector_lastmonth_pivot.merge(subsector_before_lastmonth_pivot,on='card_id',how='left')

# %%
train_df = all_df.loc[all_df['target'].notnull()]

# %%
subsector_id = subsector_id.merge(train_df[['card_id','target']],on='card_id',how='left')

# %%
subsector_id_train = subsector_id.loc[subsector_id['target'].notnull()]
subsector_id_test = subsector_id.loc[subsector_id['target'].isnull()]

# %%
subsector_id_train['outliers'] = 0
subsector_id_train.loc[subsector_id_train['target'] < -30, 'outliers'] = 1

train_columns = [c for c in subsector_id_train.columns if c not in ['card_id', 'first_active_month','target','outliers','rank']]
train_columns
# Out:
# ['lastmonth_merchant_category_id_-1',
#  'lastmonth_merchant_category_id_2',
#  'lastmonth_merchant_category_id_9',
#  'lastmonth_merchant_category_id_11',
#  'lastmonth_merchant_category_id_14',
#  'lastmonth_merchant_category_id_16',
#  'lastmonth_merchant_category_id_19',
#  'lastmonth_merchant_category_id_21',
#  'lastmonth_merchant_category_id_27',
#  'lastmonth_merchant_category_id_33',
#  'lastmonth_merchant_category_id_34',
#  'lastmonth_merchant_category_id_36',
#  'lastmonth_merchant_category_id_38',
#  'lastmonth_merchant_category_id_40',
#  'lastmonth_merchant_category_id_45',
#  'lastmonth_merchant_category_id_49',
#  'lastmonth_merchant_category_id_52',
#  'lastmonth_merchant_category_id_53',
#  'lastmonth_merchant_category_id_56',
#  'lastmonth_merchant_category_id_57',
#  'lastmonth_merchant_category_id_60',
#  'lastmonth_merchant_category_id_63',
#  'lastmonth_merchant_category_id_67',
#  'lastmonth_merchant_category_id_68',
#  'lastmonth_merchant_category_id_69',
#  'lastmonth_merchant_category_id_71',
#  'lastmonth_merchant_category_id_78',
#  'lastmonth_merchant_category_id_80',
#  'lastmonth_merchant_category_id_81',
#  'lastmonth_merchant_category_id_83',
#  'lastmonth_merchant_category_id_87',
#  'lastmonth_merchant_category_id_90',
#  'lastmonth_merchant_category_id_101',
#  'lastmonth_merchant_category_id_105',
#  'lastmonth_merchant_category_id_108',
#  'lastmonth_merchant_category_id_109',
#  'lastmonth_merchant_category_id_110',
#  'lastmonth_merchant_category_id_111',
#  'lastmonth_merchant_category_id_114',
#  'lastmonth_merchant_category_id_115',
#  'lastmonth_merchant_category_id_117',
#  'lastmonth_merchant_category_id_119',
#  'lastmonth_merchant_category_id_126',
#  'lastmonth_merchant_category_id_130',
#  'lastmonth_merchant_category_id_131',
#  'lastmonth_merchant_category_id_140',
#  'lastmonth_merchant_category_id_141',
#  'lastmonth_merchant_category_id_145',
#  'lastmonth_merchant_category_id_154',
#  'lastmonth_merchant_category_id_157',
#  'lastmonth_merchant_category_id_162',
#  'lastmonth_merchant_category_id_166',
#  'lastmonth_merchant_category_id_171',
#  'lastmonth_merchant_category_id_172',
#  'lastmonth_merchant_category_id_178',
#  'lastmonth_merchant_category_id_179',
#  'lastmonth_merchant_category_id_180',
#  'lastmonth_merchant_category_id_181',
#  'lastmonth_merchant_category_id_182',
#  'lastmonth_merchant_category_id_183',
#  'lastmonth_merchant_category_id_184',
#  'lastmonth_merchant_category_id_187',
#  'lastmonth_merchant_category_id_190',
#  'lastmonth_merchant_category_id_192',
#  'lastmonth_merchant_category_id_195',
#  'lastmonth_merchant_category_id_198',
#  'lastmonth_merchant_category_id_201',
#  'lastmonth_merchant_category_id_206',
#  'lastmonth_merchant_category_id_209',
#  'lastmonth_merchant_category_id_210',
#  'lastmonth_merchant_category_id_215',
#  'lastmonth_merchant_category_id_216',
#  'lastmonth_merchant_category_id_217',
#  'lastmonth_merchant_category_id_222',
#  'lastmonth_merchant_category_id_223',
#  'lastmonth_merchant_category_id_224',
#  'lastmonth_merchant_category_id_225',
#  'lastmonth_merchant_category_id_241',
#  'lastmonth_merchant_category_id_245',
#  'lastmonth_merchant_category_id_246',
#  'lastmonth_merchant_category_id_247',
#  'lastmonth_merchant_category_id_248',
#  'lastmonth_merchant_category_id_249',
#  'lastmonth_merchant_category_id_259',
#  'lastmonth_merchant_category_id_260',
#  'lastmonth_merchant_category_id_261',
#  'lastmonth_merchant_category_id_265',
#  'lastmonth_merchant_category_id_267',
#  'lastmonth_merchant_category_id_268',
#  'lastmonth_merchant_category_id_273',
#  'lastmonth_merchant_category_id_274',
#  'lastmonth_merchant_category_id_276',
#  'lastmonth_merchant_category_id_278',
#  'lastmonth_merchant_category_id_289',
#  'lastmonth_merchant_category_id_290',
#  'lastmonth_merchant_category_id_292',
#  'lastmonth_merchant_category_id_298',
#  'lastmonth_merchant_category_id_299',
#  'lastmonth_merchant_category_id_302',
#  'lastmonth_merchant_category_id_307',
#  'lastmonth_merchant_category_id_309',
#  'lastmonth_merchant_category_id_312',
#  'lastmonth_merchant_category_id_315',
#  'lastmonth_merchant_category_id_317',
#  'lastmonth_merchant_category_id_319',
#  'lastmonth_merchant_category_id_320',
#  'lastmonth_merchant_category_id_330',
#  'lastmonth_merchant_category_id_332',
#  'lastmonth_merchant_category_id_333',
#  'lastmonth_merchant_category_id_334',
#  'lastmonth_merchant_category_id_340',
#  'lastmonth_merchant_category_id_342',
#  'lastmonth_merchant_category_id_343',
#  'lastmonth_merchant_category_id_345',
#  'lastmonth_merchant_category_id_348',
#  'lastmonth_merchant_category_id_351',
#  'lastmonth_merchant_category_id_355',
#  'lastmonth_merchant_category_id_356',
#  'lastmonth_merchant_category_id_357',
#  'lastmonth_merchant_category_id_358',
#  'lastmonth_merchant_category_id_360',
#  'lastmonth_merchant_category_id_363',
#  'lastmonth_merchant_category_id_367',
#  'lastmonth_merchant_category_id_369',
#  'lastmonth_merchant_category_id_373',
#  'lastmonth_merchant_category_id_374',
#  'lastmonth_merchant_category_id_381',
#  'lastmonth_merchant_category_id_383',
#  'lastmonth_merchant_category_id_384',
#  'lastmonth_merchant_category_id_385',
#  'lastmonth_merchant_category_id_386',
#  'lastmonth_merchant_category_id_387',
#  'lastmonth_merchant_category_id_391',
#  'lastmonth_merchant_category_id_393',
#  'lastmonth_merchant_category_id_396',
#  'lastmonth_merchant_category_id_398',
#  'lastmonth_merchant_category_id_400',
#  'lastmonth_merchant_category_id_401',
#  'lastmonth_merchant_category_id_409',
#  'lastmonth_merchant_category_id_411',
#  'lastmonth_merchant_category_id_412',
#  'lastmonth_merchant_category_id_414',
#  'lastmonth_merchant_category_id_415',
#  'lastmonth_merchant_category_id_416',
#  'lastmonth_merchant_category_id_417',
#  'lastmonth_merchant_category_id_419',
#  'lastmonth_merchant_category_id_420',
#  'lastmonth_merchant_category_id_421',
#  'lastmonth_merchant_category_id_422',
#  'lastmonth_merchant_category_id_427',
#  'lastmonth_merchant_category_id_430',
#  'lastmonth_merchant_category_id_432',
#  'lastmonth_merchant_category_id_434',
#  'lastmonth_merchant_category_id_436',
#  'lastmonth_merchant_category_id_437',
#  'lastmonth_merchant_category_id_438',
#  'lastmonth_merchant_category_id_443',
#  'lastmonth_merchant_category_id_448',
#  'lastmonth_merchant_category_id_451',
#  'lastmonth_merchant_category_id_454',
#  'lastmonth_merchant_category_id_456',
#  'lastmonth_merchant_category_id_457',
#  'lastmonth_merchant_category_id_458',
#  'lastmonth_merchant_category_id_462',
#  'lastmonth_merchant_category_id_464',
#  'lastmonth_merchant_category_id_469',
#  'lastmonth_merchant_category_id_471',
#  'lastmonth_merchant_category_id_472',
#  'lastmonth_merchant_category_id_474',
#  'lastmonth_merchant_category_id_478',
#  'lastmonth_merchant_category_id_480',
#  'lastmonth_merchant_category_id_482',
#  'lastmonth_merchant_category_id_489',
#  'lastmonth_merchant_category_id_491',
#  'lastmonth_merchant_category_id_497',
#  'lastmonth_merchant_category_id_498',
#  'lastmonth_merchant_category_id_499',
#  'lastmonth_merchant_category_id_504',
#  'lastmonth_merchant_category_id_506',
#  'lastmonth_merchant_category_id_507',
#  'lastmonth_merchant_category_id_509',
#  'lastmonth_merchant_category_id_511',
#  'lastmonth_merchant_category_id_513',
#  'lastmonth_merchant_category_id_514',
#  'lastmonth_merchant_category_id_518',
#  'lastmonth_merchant_category_id_519',
#  'lastmonth_merchant_category_id_523',
#  'lastmonth_merchant_category_id_526',
#  'lastmonth_merchant_category_id_527',
#  'lastmonth_merchant_category_id_528',
#  'lastmonth_merchant_category_id_529',
#  'lastmonth_merchant_category_id_530',
#  'lastmonth_merchant_category_id_531',
#  'lastmonth_merchant_category_id_534',
#  'lastmonth_merchant_category_id_536',
#  'lastmonth_merchant_category_id_542',
#  'lastmonth_merchant_category_id_544',
#  'lastmonth_merchant_category_id_546',
#  'lastmonth_merchant_category_id_550',
#  'lastmonth_merchant_category_id_551',
#  'lastmonth_merchant_category_id_554',
#  'lastmonth_merchant_category_id_556',
#  'lastmonth_merchant_category_id_557',
#  'lastmonth_merchant_category_id_560',
#  'lastmonth_merchant_category_id_561',
#  'lastmonth_merchant_category_id_568',
#  'lastmonth_merchant_category_id_573',
#  'lastmonth_merchant_category_id_574',
#  'lastmonth_merchant_category_id_580',
#  'lastmonth_merchant_category_id_583',
#  'lastmonth_merchant_category_id_587',
#  'lastmonth_merchant_category_id_591',
#  'lastmonth_merchant_category_id_593',
#  'lastmonth_merchant_category_id_598',
#  'lastmonth_merchant_category_id_599',
#  'lastmonth_merchant_category_id_605',
#  'lastmonth_merchant_category_id_606',
#  'lastmonth_merchant_category_id_607',
#  'lastmonth_merchant_category_id_613',
#  'lastmonth_merchant_category_id_614',
#  'lastmonth_merchant_category_id_623',
#  'lastmonth_merchant_category_id_628',
#  'lastmonth_merchant_category_id_630',
#  'lastmonth_merchant_category_id_631',
#  'lastmonth_merchant_category_id_637',
#  'lastmonth_merchant_category_id_642',
#  'lastmonth_merchant_category_id_645',
#  'lastmonth_merchant_category_id_648',
#  'lastmonth_merchant_category_id_650',
#  'lastmonth_merchant_category_id_651',
#  'lastmonth_merchant_category_id_652',
#  'lastmonth_merchant_category_id_653',
#  'lastmonth_merchant_category_id_656',
#  'lastmonth_merchant_category_id_661',
#  'lastmonth_merchant_category_id_662',
#  'lastmonth_merchant_category_id_664',
#  'lastmonth_merchant_category_id_665',
#  'lastmonth_merchant_category_id_667',
#  'lastmonth_merchant_category_id_668',
#  'lastmonth_merchant_category_id_669',
#  'lastmonth_merchant_category_id_670',
#  'lastmonth_merchant_category_id_671',
#  'lastmonth_merchant_category_id_676',
#  'lastmonth_merchant_category_id_683',
#  'lastmonth_merchant_category_id_685',
#  'lastmonth_merchant_category_id_686',
#  'lastmonth_merchant_category_id_690',
#  'lastmonth_merchant_category_id_692',
#  'lastmonth_merchant_category_id_695',
#  'lastmonth_merchant_category_id_696',
#  'lastmonth_merchant_category_id_702',
#  'lastmonth_merchant_category_id_703',
#  'lastmonth_merchant_category_id_705',
#  'lastmonth_merchant_category_id_706',
#  'lastmonth_merchant_category_id_712',
#  'lastmonth_merchant_category_id_713',
#  'lastmonth_merchant_category_id_714',
#  'lastmonth_merchant_category_id_717',
#  'lastmonth_merchant_category_id_718',
#  'lastmonth_merchant_category_id_734',
#  'lastmonth_merchant_category_id_737',
#  'lastmonth_merchant_category_id_741',
#  'lastmonth_merchant_category_id_743',
#  'lastmonth_merchant_category_id_748',
#  'lastmonth_merchant_category_id_751',
#  'lastmonth_merchant_category_id_755',
#  'lastmonth_merchant_category_id_757',
#  'lastmonth_merchant_category_id_761',
#  'lastmonth_merchant_category_id_763',
#  'lastmonth_merchant_category_id_769',
#  'lastmonth_merchant_category_id_771',
#  'lastmonth_merchant_category_id_774',
#  'lastmonth_merchant_category_id_779',
#  'lastmonth_merchant_category_id_780',
#  'lastmonth_merchant_category_id_781',
#  'lastmonth_merchant_category_id_783',
#  'lastmonth_merchant_category_id_790',
#  'lastmonth_merchant_category_id_792',
#  'lastmonth_merchant_category_id_793',
#  'lastmonth_merchant_category_id_795',
#  'lastmonth_merchant_category_id_796',
#  'lastmonth_merchant_category_id_803',
#  'lastmonth_merchant_category_id_806',
#  'lastmonth_merchant_category_id_808',
#  'lastmonth_merchant_category_id_813',
#  'lastmonth_merchant_category_id_814',
#  'lastmonth_merchant_category_id_818',
#  'lastmonth_merchant_category_id_819',
#  'lastmonth_merchant_category_id_823',
#  'lastmonth_merchant_category_id_827',
#  'lastmonth_merchant_category_id_829',
#  'lastmonth_merchant_category_id_834',
#  'lastmonth_merchant_category_id_836',
#  'lastmonth_merchant_category_id_839',
#  'lastmonth_merchant_category_id_840',
#  'lastmonth_merchant_category_id_842',
#  'lastmonth_merchant_category_id_843',
#  'lastmonth_merchant_category_id_847',
#  'lastmonth_merchant_category_id_854',
#  'lastmonth_merchant_category_id_873',
#  'lastmonth_merchant_category_id_878',
#  'lastmonth_merchant_category_id_879',
#  'lastmonth_merchant_category_id_881',
#  'lastmonth_merchant_category_id_884',
#  'lastmonth_merchant_category_id_885',
#  'lastmonth_merchant_category_id_889',
#  'lastmonth_merchant_category_id_891',
#  'before_lastmonth_merchant_category_id_-1',
#  'before_lastmonth_merchant_category_id_2',
#  'before_lastmonth_merchant_category_id_9',
#  'before_lastmonth_merchant_category_id_11',
#  'before_lastmonth_merchant_category_id_14',
#  'before_lastmonth_merchant_category_id_16',
#  'before_lastmonth_merchant_category_id_18',
#  'before_lastmonth_merchant_category_id_19',
#  'before_lastmonth_merchant_category_id_21',
#  'before_lastmonth_merchant_category_id_27',
#  'before_lastmonth_merchant_category_id_31',
#  'before_lastmonth_merchant_category_id_33',
#  'before_lastmonth_merchant_category_id_34',
#  'before_lastmonth_merchant_category_id_36',
#  'before_lastmonth_merchant_category_id_37',
#  'before_lastmonth_merchant_category_id_38',
#  'before_lastmonth_merchant_category_id_40',
#  'before_lastmonth_merchant_category_id_45',
#  'before_lastmonth_merchant_category_id_49',
#  'before_lastmonth_merchant_category_id_52',
#  'before_lastmonth_merchant_category_id_53',
#  'before_lastmonth_merchant_category_id_56',
#  'before_lastmonth_merchant_category_id_57',
#  'before_lastmonth_merchant_category_id_59',
#  'before_lastmonth_merchant_category_id_60',
#  'before_lastmonth_merchant_category_id_63',
#  'before_lastmonth_merchant_category_id_67',
#  'before_lastmonth_merchant_category_id_68',
#  'before_lastmonth_merchant_category_id_69',
#  'before_lastmonth_merchant_category_id_71',
#  'before_lastmonth_merchant_category_id_78',
#  'before_lastmonth_merchant_category_id_80',
#  'before_lastmonth_merchant_category_id_81',
#  'before_lastmonth_merchant_category_id_83',
#  'before_lastmonth_merchant_category_id_86',
#  'before_lastmonth_merchant_category_id_87',
#  'before_lastmonth_merchant_category_id_90',
#  'before_lastmonth_merchant_category_id_101',
#  'before_lastmonth_merchant_category_id_105',
#  'before_lastmonth_merchant_category_id_108',
#  'before_lastmonth_merchant_category_id_109',
#  'before_lastmonth_merchant_category_id_110',
#  'before_lastmonth_merchant_category_id_111',
#  'before_lastmonth_merchant_category_id_114',
#  'before_lastmonth_merchant_category_id_115',
#  'before_lastmonth_merchant_category_id_117',
#  'before_lastmonth_merchant_category_id_119',
#  'before_lastmonth_merchant_category_id_126',
#  'before_lastmonth_merchant_category_id_130',
#  'before_lastmonth_merchant_category_id_131',
#  'before_lastmonth_merchant_category_id_140',
#  'before_lastmonth_merchant_category_id_141',
#  'before_lastmonth_merchant_category_id_145',
#  'before_lastmonth_merchant_category_id_153',
#  'before_lastmonth_merchant_category_id_154',
#  'before_lastmonth_merchant_category_id_157',
#  'before_lastmonth_merchant_category_id_162',
#  'before_lastmonth_merchant_category_id_164',
#  'before_lastmonth_merchant_category_id_166',
#  'before_lastmonth_merchant_category_id_171',
#  'before_lastmonth_merchant_category_id_172',
#  'before_lastmonth_merchant_category_id_178',
#  'before_lastmonth_merchant_category_id_179',
#  'before_lastmonth_merchant_category_id_180',
#  'before_lastmonth_merchant_category_id_181',
#  'before_lastmonth_merchant_category_id_182',
#  'before_lastmonth_merchant_category_id_183',
#  'before_lastmonth_merchant_category_id_184',
#  'before_lastmonth_merchant_category_id_187',
#  'before_lastmonth_merchant_category_id_190',
#  'before_lastmonth_merchant_category_id_192',
#  'before_lastmonth_merchant_category_id_195',
#  'before_lastmonth_merchant_category_id_198',
#  'before_lastmonth_merchant_category_id_201',
#  'before_lastmonth_merchant_category_id_206',
#  'before_lastmonth_merchant_category_id_209',
#  'before_lastmonth_merchant_category_id_210',
#  'before_lastmonth_merchant_category_id_215',
#  'before_lastmonth_merchant_category_id_216',
#  'before_lastmonth_merchant_category_id_217',
#  'before_lastmonth_merchant_category_id_222',
#  'before_lastmonth_merchant_category_id_223',
#  'before_lastmonth_merchant_category_id_224',
#  'before_lastmonth_merchant_category_id_225',
#  'before_lastmonth_merchant_category_id_226',
#  'before_lastmonth_merchant_category_id_241',
#  'before_lastmonth_merchant_category_id_245',
#  'before_lastmonth_merchant_category_id_246',
#  'before_lastmonth_merchant_category_id_247',
#  'before_lastmonth_merchant_category_id_248',
#  'before_lastmonth_merchant_category_id_249',
#  'before_lastmonth_merchant_category_id_259',
#  'before_lastmonth_merchant_category_id_260',
#  'before_lastmonth_merchant_category_id_261',
#  'before_lastmonth_merchant_category_id_265',
#  'before_lastmonth_merchant_category_id_266',
#  'before_lastmonth_merchant_category_id_267',
#  'before_lastmonth_merchant_category_id_268',
#  'before_lastmonth_merchant_category_id_273',
#  'before_lastmonth_merchant_category_id_274',
#  'before_lastmonth_merchant_category_id_276',
#  'before_lastmonth_merchant_category_id_278',
#  'before_lastmonth_merchant_category_id_289',
#  'before_lastmonth_merchant_category_id_290',
#  'before_lastmonth_merchant_category_id_292',
#  'before_lastmonth_merchant_category_id_298',
#  'before_lastmonth_merchant_category_id_299',
#  'before_lastmonth_merchant_category_id_302',
#  'before_lastmonth_merchant_category_id_307',
#  'before_lastmonth_merchant_category_id_309',
#  'before_lastmonth_merchant_category_id_311',
#  'before_lastmonth_merchant_category_id_312',
#  'before_lastmonth_merchant_category_id_315',
#  'before_lastmonth_merchant_category_id_317',
#  'before_lastmonth_merchant_category_id_319',
#  'before_lastmonth_merchant_category_id_320',
#  'before_lastmonth_merchant_category_id_322',
#  'before_lastmonth_merchant_category_id_330',
#  'before_lastmonth_merchant_category_id_332',
#  'before_lastmonth_merchant_category_id_333',
#  'before_lastmonth_merchant_category_id_334',
#  'before_lastmonth_merchant_category_id_340',
#  'before_lastmonth_merchant_category_id_342',
#  'before_lastmonth_merchant_category_id_343',
#  'before_lastmonth_merchant_category_id_345',
#  'before_lastmonth_merchant_category_id_348',
#  'before_lastmonth_merchant_category_id_351',
#  'before_lastmonth_merchant_category_id_355',
#  'before_lastmonth_merchant_category_id_356',
#  'before_lastmonth_merchant_category_id_357',
#  'before_lastmonth_merchant_category_id_358',
#  'before_lastmonth_merchant_category_id_360',
#  'before_lastmonth_merchant_category_id_363',
#  'before_lastmonth_merchant_category_id_367',
#  'before_lastmonth_merchant_category_id_369',
#  'before_lastmonth_merchant_category_id_373',
#  'before_lastmonth_merchant_category_id_374',
#  'before_lastmonth_merchant_category_id_381',
#  'before_lastmonth_merchant_category_id_383',
#  'before_lastmonth_merchant_category_id_384',
#  'before_lastmonth_merchant_category_id_385',
#  'before_lastmonth_merchant_category_id_386',
#  'before_lastmonth_merchant_category_id_387',
#  'before_lastmonth_merchant_category_id_391',
#  'before_lastmonth_merchant_category_id_393',
#  'before_lastmonth_merchant_category_id_396',
#  'before_lastmonth_merchant_category_id_398',
#  'before_lastmonth_merchant_category_id_400',
#  'before_lastmonth_merchant_category_id_401',
#  'before_lastmonth_merchant_category_id_409',
#  'before_lastmonth_merchant_category_id_411',
#  'before_lastmonth_merchant_category_id_412',
#  'before_lastmonth_merchant_category_id_414',
#  'before_lastmonth_merchant_category_id_415',
#  'before_lastmonth_merchant_category_id_416',
#  'before_lastmonth_merchant_category_id_417',
#  'before_lastmonth_merchant_category_id_419',
#  'before_lastmonth_merchant_category_id_420',
#  'before_lastmonth_merchant_category_id_421',
#  'before_lastmonth_merchant_category_id_422',
#  'before_lastmonth_merchant_category_id_427',
#  'before_lastmonth_merchant_category_id_430',
#  'before_lastmonth_merchant_category_id_432',
#  'before_lastmonth_merchant_category_id_434',
#  'before_lastmonth_merchant_category_id_436',
#  'before_lastmonth_merchant_category_id_437',
#  'before_lastmonth_merchant_category_id_438',
#  'before_lastmonth_merchant_category_id_443',
#  'before_lastmonth_merchant_category_id_448',
#  'before_lastmonth_merchant_category_id_451',
#  'before_lastmonth_merchant_category_id_454',
#  'before_lastmonth_merchant_category_id_456',
#  'before_lastmonth_merchant_category_id_457',
#  'before_lastmonth_merchant_category_id_458',
#  'before_lastmonth_merchant_category_id_462',
#  'before_lastmonth_merchant_category_id_464',
#  'before_lastmonth_merchant_category_id_469',
#  'before_lastmonth_merchant_category_id_471',
#  'before_lastmonth_merchant_category_id_472',
#  'before_lastmonth_merchant_category_id_474',
#  'before_lastmonth_merchant_category_id_478',
#  'before_lastmonth_merchant_category_id_480',
#  'before_lastmonth_merchant_category_id_482',
#  'before_lastmonth_merchant_category_id_489',
#  'before_lastmonth_merchant_category_id_491',
#  'before_lastmonth_merchant_category_id_497',
#  'before_lastmonth_merchant_category_id_498',
#  'before_lastmonth_merchant_category_id_499',
#  'before_lastmonth_merchant_category_id_504',
#  'before_lastmonth_merchant_category_id_506',
#  'before_lastmonth_merchant_category_id_507',
#  'before_lastmonth_merchant_category_id_509',
#  'before_lastmonth_merchant_category_id_511',
#  'before_lastmonth_merchant_category_id_513',
#  'before_lastmonth_merchant_category_id_514',
#  'before_lastmonth_merchant_category_id_518',
#  'before_lastmonth_merchant_category_id_519',
#  'before_lastmonth_merchant_category_id_523',
#  'before_lastmonth_merchant_category_id_526',
#  'before_lastmonth_merchant_category_id_527',
#  'before_lastmonth_merchant_category_id_528',
#  'before_lastmonth_merchant_category_id_529',
#  'before_lastmonth_merchant_category_id_530',
#  'before_lastmonth_merchant_category_id_531',
#  'before_lastmonth_merchant_category_id_534',
#  'before_lastmonth_merchant_category_id_536',
#  'before_lastmonth_merchant_category_id_542',
#  'before_lastmonth_merchant_category_id_544',
#  'before_lastmonth_merchant_category_id_546',
#  'before_lastmonth_merchant_category_id_550',
#  'before_lastmonth_merchant_category_id_551',
#  'before_lastmonth_merchant_category_id_554',
#  'before_lastmonth_merchant_category_id_556',
#  'before_lastmonth_merchant_category_id_557',
#  'before_lastmonth_merchant_category_id_560',
#  'before_lastmonth_merchant_category_id_561',
#  'before_lastmonth_merchant_category_id_568',
#  'before_lastmonth_merchant_category_id_573',
#  'before_lastmonth_merchant_category_id_574',
#  'before_lastmonth_merchant_category_id_579',
#  'before_lastmonth_merchant_category_id_580',
#  'before_lastmonth_merchant_category_id_583',
#  'before_lastmonth_merchant_category_id_587',
#  'before_lastmonth_merchant_category_id_591',
#  'before_lastmonth_merchant_category_id_593',
#  'before_lastmonth_merchant_category_id_598',
#  'before_lastmonth_merchant_category_id_599',
#  'before_lastmonth_merchant_category_id_601',
#  'before_lastmonth_merchant_category_id_603',
#  'before_lastmonth_merchant_category_id_605',
#  'before_lastmonth_merchant_category_id_606',
#  'before_lastmonth_merchant_category_id_607',
#  'before_lastmonth_merchant_category_id_613',
#  'before_lastmonth_merchant_category_id_614',
#  'before_lastmonth_merchant_category_id_623',
#  'before_lastmonth_merchant_category_id_628',
#  'before_lastmonth_merchant_category_id_630',
#  'before_lastmonth_merchant_category_id_631',
#  'before_lastmonth_merchant_category_id_634',
#  'before_lastmonth_merchant_category_id_637',
#  'before_lastmonth_merchant_category_id_642',
#  'before_lastmonth_merchant_category_id_645',
#  'before_lastmonth_merchant_category_id_648',
#  'before_lastmonth_merchant_category_id_650',
#  'before_lastmonth_merchant_category_id_651',
#  'before_lastmonth_merchant_category_id_652',
#  'before_lastmonth_merchant_category_id_653',
#  'before_lastmonth_merchant_category_id_656',
#  'before_lastmonth_merchant_category_id_661',
#  'before_lastmonth_merchant_category_id_662',
#  'before_lastmonth_merchant_category_id_664',
#  'before_lastmonth_merchant_category_id_665',
#  'before_lastmonth_merchant_category_id_667',
#  'before_lastmonth_merchant_category_id_668',
#  'before_lastmonth_merchant_category_id_669',
#  'before_lastmonth_merchant_category_id_670',
#  'before_lastmonth_merchant_category_id_671',
#  'before_lastmonth_merchant_category_id_676',
#  'before_lastmonth_merchant_category_id_683',
#  'before_lastmonth_merchant_category_id_685',
#  'before_lastmonth_merchant_category_id_686',
#  'before_lastmonth_merchant_category_id_687',
#  'before_lastmonth_merchant_category_id_690',
#  'before_lastmonth_merchant_category_id_692',
#  'before_lastmonth_merchant_category_id_695',
#  'before_lastmonth_merchant_category_id_696',
#  'before_lastmonth_merchant_category_id_702',
#  'before_lastmonth_merchant_category_id_703',
#  'before_lastmonth_merchant_category_id_705',
#  'before_lastmonth_merchant_category_id_706',
#  'before_lastmonth_merchant_category_id_712',
#  'before_lastmonth_merchant_category_id_713',
#  'before_lastmonth_merchant_category_id_714',
#  'before_lastmonth_merchant_category_id_717',
#  'before_lastmonth_merchant_category_id_718',
#  'before_lastmonth_merchant_category_id_734',
#  'before_lastmonth_merchant_category_id_737',
#  'before_lastmonth_merchant_category_id_741',
#  'before_lastmonth_merchant_category_id_743',
#  'before_lastmonth_merchant_category_id_748',
#  'before_lastmonth_merchant_category_id_751',
#  'before_lastmonth_merchant_category_id_755',
#  'before_lastmonth_merchant_category_id_757',
#  'before_lastmonth_merchant_category_id_761',
#  'before_lastmonth_merchant_category_id_763',
#  'before_lastmonth_merchant_category_id_769',
#  'before_lastmonth_merchant_category_id_771',
#  'before_lastmonth_merchant_category_id_774',
#  'before_lastmonth_merchant_category_id_779',
#  'before_lastmonth_merchant_category_id_780',
#  'before_lastmonth_merchant_category_id_781',
#  'before_lastmonth_merchant_category_id_783',
#  'before_lastmonth_merchant_category_id_790',
#  'before_lastmonth_merchant_category_id_792',
#  'before_lastmonth_merchant_category_id_793',
#  'before_lastmonth_merchant_category_id_795',
#  'before_lastmonth_merchant_category_id_796',
#  'before_lastmonth_merchant_category_id_803',
#  'before_lastmonth_merchant_category_id_805',
#  'before_lastmonth_merchant_category_id_806',
#  'before_lastmonth_merchant_category_id_808',
#  'before_lastmonth_merchant_category_id_813',
#  'before_lastmonth_merchant_category_id_814',
#  'before_lastmonth_merchant_category_id_817',
#  'before_lastmonth_merchant_category_id_818',
#  'before_lastmonth_merchant_category_id_819',
#  'before_lastmonth_merchant_category_id_823',
#  'before_lastmonth_merchant_category_id_827',
#  'before_lastmonth_merchant_category_id_829',
#  'before_lastmonth_merchant_category_id_834',
#  'before_lastmonth_merchant_category_id_836',
#  'before_lastmonth_merchant_category_id_839',
#  'before_lastmonth_merchant_category_id_840',
#  'before_lastmonth_merchant_category_id_842',
#  'before_lastmonth_merchant_category_id_843',
#  'before_lastmonth_merchant_category_id_847',
#  'before_lastmonth_merchant_category_id_854',
#  'before_lastmonth_merchant_category_id_873',
#  'before_lastmonth_merchant_category_id_875',
#  'before_lastmonth_merchant_category_id_878',
#  'before_lastmonth_merchant_category_id_879',
#  'before_lastmonth_merchant_category_id_881',
#  'before_lastmonth_merchant_category_id_882',
#  'before_lastmonth_merchant_category_id_884',
#  'before_lastmonth_merchant_category_id_885',
#  'before_lastmonth_merchant_category_id_889',
#  'before_lastmonth_merchant_category_id_891']

# %%
train = subsector_id_train.copy()
target = train['target']
del train['target']

# %%
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.015,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 24,
         "seed": 6}

#prepare fit model with cross-validation
np.random.seed(2019)


feature_importance_df = pd.DataFrame()
folds = KFold(n_splits=9, shuffle=True, random_state=4950)
oof = np.zeros(len(train))
predictions = np.zeros(len(test_df))
cv_score_list = []
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, train['outliers'].values)):
    strLog = "fold {}".format(fold_+1)
    print(strLog)
    trn_data = lgb.Dataset(train.iloc[trn_idx][train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 100)
    oof[val_idx] = clf.predict(train.iloc[val_idx][train_columns], num_iteration=clf.best_iteration)
    
    cv_score = np.sqrt(mean_squared_error(oof[val_idx], target.iloc[val_idx]))
    cv_score_list.append(cv_score)
    #feature importance
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    #predictions
    predictions += clf.predict(subsector_id_test[train_columns], num_iteration=clf.best_iteration) / folds.n_splits

cv_score = np.sqrt(mean_squared_error(oof, target))
print(cv_score)
print(cv_score_list)
print(np.std(cv_score_list))
withoutoutlier_predictions = predictions.copy()
# Out:
# fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.83379	valid_1's rmse: 3.66421
# [200]	training's rmse: 3.80959	valid_1's rmse: 3.66558
# Early stopping, best iteration is:
# [110]	training's rmse: 3.83095	valid_1's rmse: 3.66411
# fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.80703	valid_1's rmse: 3.89815
# [200]	training's rmse: 3.78399	valid_1's rmse: 3.895
# [300]	training's rmse: 3.76623	valid_1's rmse: 3.89458
# Early stopping, best iteration is:
# [275]	training's rmse: 3.77036	valid_1's rmse: 3.89435
# fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.80558	valid_1's rmse: 3.90321
# [200]	training's rmse: 3.78215	valid_1's rmse: 3.90002
# [300]	training's rmse: 3.76451	valid_1's rmse: 3.89886
# [400]	training's rmse: 3.74979	valid_1's rmse: 3.89881
# Early stopping, best iteration is:
# [340]	training's rmse: 3.75831	valid_1's rmse: 3.89844
# fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.82434	valid_1's rmse: 3.74819
# [200]	training's rmse: 3.80059	valid_1's rmse: 3.74583
# [300]	training's rmse: 3.78238	valid_1's rmse: 3.74528
# Early stopping, best iteration is:
# [294]	training's rmse: 3.78343	valid_1's rmse: 3.74516
# fold 5
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.80687	valid_1's rmse: 3.8886
# [200]	training's rmse: 3.78337	valid_1's rmse: 3.88529
# [300]	training's rmse: 3.76561	valid_1's rmse: 3.88374
# [400]	training's rmse: 3.75079	valid_1's rmse: 3.88331
# [500]	training's rmse: 3.73756	valid_1's rmse: 3.88276
# [600]	training's rmse: 3.72547	valid_1's rmse: 3.88279
# [700]	training's rmse: 3.71448	valid_1's rmse: 3.88275
# Early stopping, best iteration is:
# [663]	training's rmse: 3.71861	valid_1's rmse: 3.88261
# fold 6
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81295	valid_1's rmse: 3.83926
# [200]	training's rmse: 3.78976	valid_1's rmse: 3.83601
# [300]	training's rmse: 3.77267	valid_1's rmse: 3.83586
# [400]	training's rmse: 3.75745	valid_1's rmse: 3.83475
# [500]	training's rmse: 3.74472	valid_1's rmse: 3.83503
# Early stopping, best iteration is:
# [414]	training's rmse: 3.75557	valid_1's rmse: 3.83465
# fold 7
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.83013	valid_1's rmse: 3.70313
# [200]	training's rmse: 3.80655	valid_1's rmse: 3.69908
# [300]	training's rmse: 3.78849	valid_1's rmse: 3.69835
# Early stopping, best iteration is:
# [293]	training's rmse: 3.78962	valid_1's rmse: 3.69827
# fold 8
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.7887	valid_1's rmse: 4.03837
# [200]	training's rmse: 3.76603	valid_1's rmse: 4.03406
# [300]	training's rmse: 3.74841	valid_1's rmse: 4.03219
# [400]	training's rmse: 3.73377	valid_1's rmse: 4.03128
# [500]	training's rmse: 3.72123	valid_1's rmse: 4.03104
# [600]	training's rmse: 3.70978	valid_1's rmse: 4.03105
# Early stopping, best iteration is:
# [511]	training's rmse: 3.71996	valid_1's rmse: 4.03086
# fold 9
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81155	valid_1's rmse: 3.8495
# [200]	training's rmse: 3.78793	valid_1's rmse: 3.84634
# [300]	training's rmse: 3.76982	valid_1's rmse: 3.84538
# Early stopping, best iteration is:
# [296]	training's rmse: 3.77048	valid_1's rmse: 3.84529
# 3.8341484018128122
# [3.6641132000167693, 3.894351946948629, 3.898440698034394, 3.745165055615986, 3.882612309406068, 3.8346498252933907, 3.6982682387082613, 4.0308580566877374, 3.8452900708364584]
# 0.10759941557052022

# %%
subsector_train_pred = pd.concat([pd.DataFrame(train['card_id']).reset_index(drop=True),pd.DataFrame(oof, columns=['merchant_category_id_pred'])],axis=1)
subsector_test_pred = pd.concat([pd.DataFrame(test_df['card_id']).reset_index(drop=True),pd.DataFrame(predictions, columns=['merchant_category_id_pred'])],axis=1)
subsector_pred = pd.concat([subsector_train_pred,subsector_test_pred])
subsector_pred.to_csv('merchant_category_id_pred.csv',index=False)
