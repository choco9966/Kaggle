# %%
import gc
from datetime import datetime, timedelta,date
import warnings
import itertools
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.random_projection import GaussianRandomProjection
from sklearn.random_projection import SparseRandomProjection,johnson_lindenstrauss_min_dim
from sklearn.decomposition import PCA, FastICA,NMF,LatentDirichletAllocation,IncrementalPCA,MiniBatchSparsePCA
from sklearn.decomposition import TruncatedSVD,FactorAnalysis,KernelPCA

import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, log_loss
from sklearn.model_selection import StratifiedKFold, KFold

from scipy.stats import ks_2samp
import tqdm

#settings
warnings.filterwarnings('ignore')
np.random.seed(2018)
pd.set_option("display.max_columns", None)
pd.set_option('display.max_rows',130)

# %% [markdown]
# ### Utility Function

# %%
def get_prefix(group_col, target_col, prefix=None):
    if isinstance(group_col, list) is True:
        g = '_'.join(group_col)
    else:
        g = group_col
    if isinstance(target_col, list) is True:
        t = '_'.join(target_col)
    else:
        t = target_col
    if prefix is not None:
        return prefix + '_' + g + '_' + t
    return g + '_' + t
    
def groupby_helper(df, group_col, target_col, agg_method, prefix_param=None):
    try:
        prefix = get_prefix(group_col, target_col, prefix_param)
        print(group_col, target_col, agg_method)
        group_df = df.groupby(group_col)[target_col].agg(agg_method)
        group_df.columns = ['{}_{}'.format(prefix, m) for m in agg_method]
    except BaseException as e:
        print(e)
    return group_df.reset_index()

# %%
def create_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %% [markdown]
# ### 데이터 Load

# %%
historical_trans_df = pd.read_csv('input/historical_transactions.csv')
new_merchant_trans_df = pd.read_csv('input/new_merchant_transactions.csv')
merchant_df = pd.read_csv('input/merchants.csv')
train_df = pd.read_csv('input/train.csv')
test_df = pd.read_csv('input/test.csv')

# %% [markdown]
# ### 기본 전처리

# %%
def get_hist_default_prorcessing(df):
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    df['category_3'] = df['category_3'].map({'A':0, 'B':1, 'C':2}) 
    df['month_diff'] = ((datetime(2012,4,1) - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']
    df['reference_date'] = (df['year']+(df['month'] - df['month_lag'])//12)*100 + (((df['month'] - df['month_lag'])%12) + 1)*1
    return df

# %%
historical_trans_df = get_hist_default_prorcessing(historical_trans_df)
new_merchant_trans_df = get_hist_default_prorcessing(new_merchant_trans_df)

# %%
historical_trans_df = historical_trans_df.sort_values('purchase_date')
new_merchant_trans_df = new_merchant_trans_df.sort_values('purchase_date')

# %%
#historical_trans_df = pd.get_dummies(historical_trans_df, columns=['category_2', 'category_3'])
#new_merchant_trans_df = pd.get_dummies(new_merchant_trans_df, columns=['category_2', 'category_3'])

# %%
authorized_transactions = historical_trans_df[historical_trans_df['authorized_flag'] == 1]
historical_transactions = historical_trans_df[historical_trans_df['authorized_flag'] == 0]

# %% [markdown]
# ### Feature Engineering

# %%
all_df = pd.concat([train_df,test_df])

# %%
historical_trans_df.loc[historical_trans_df['installments']==999,'installments_999'] = 1
new_merchant_trans_df.loc[new_merchant_trans_df['installments']==999,'installments_999'] = 1

historical_trans_df.loc[historical_trans_df['installments']==999,'installments'] = -1
new_merchant_trans_df.loc[new_merchant_trans_df['installments']==999,'installments_999'] = -1

# %%
group_df = groupby_helper(historical_trans_df,['card_id','month_lag'], 'purchase_amount',['count','mean'])
group_df['card_id_month_lag_purchase_amount_count'] = group_df['card_id_month_lag_purchase_amount_count']/(1-group_df['month_lag'])
group_df['card_id_month_lag_purchase_amount_mean'] = group_df['card_id_month_lag_purchase_amount_mean']/(1-group_df['month_lag'])
del group_df['month_lag']

count_df = groupby_helper(group_df,['card_id'], 'card_id_month_lag_purchase_amount_count',['sum','mean','std'])
mean_df = groupby_helper(group_df,['card_id'], 'card_id_month_lag_purchase_amount_mean',['sum','mean','std'])

all_df = all_df.merge(count_df, on=['card_id'], how='left')
all_df = all_df.merge(mean_df, on=['card_id'], how='left')

# %%
group_df = groupby_helper(historical_transactions,['card_id'], 'month',['nunique','max','min','mean','std'],'auth_0')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(authorized_transactions,['card_id'], 'month',['nunique','max','min','mean','std'],'auth_1')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(new_merchant_trans_df,['card_id'], 'month',['nunique','max','min','mean'],'new_hist')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
gc.collect()

# %%
group_df = groupby_helper(historical_trans_df,['card_id'], 'merchant_id',['nunique'])
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(historical_transactions,['card_id'], 'merchant_category_id',['nunique'],'auth_0')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(authorized_transactions,['card_id'], 'merchant_category_id',['nunique'],'auth_1')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(historical_transactions,['card_id'], 'subsector_id',['nunique'],'auth_0')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(authorized_transactions,['card_id'], 'subsector_id',['nunique'],'auth_1')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(historical_transactions,['card_id'], 'state_id',['nunique'],'auth_0')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
group_df = groupby_helper(authorized_transactions,['card_id'], 'state_id',['nunique'],'auth_1')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
del group_df
gc.collect()

# %%
group_df = groupby_helper(historical_trans_df,['card_id'], 'city_id',['nunique'])
all_df = all_df.merge(group_df, on=['card_id'], how='left')
group_df = groupby_helper(new_merchant_trans_df,['card_id'], 'merchant_category_id',['nunique'],'new_hist')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
group_df = groupby_helper(new_merchant_trans_df,['card_id'], 'subsector_id',['nunique'],'new_hist')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
group_df = groupby_helper(new_merchant_trans_df,['card_id'], 'state_id',['nunique'],'new_hist')
all_df = all_df.merge(group_df, on=['card_id'], how='left')

# %%
aggs = {}

for col in ['hour', 'weekofyear', 'dayofweek', 'year']:
    aggs[col] = ['nunique', 'mean', 'min', 'max']
    
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean', 'max', 'min', 'var']
aggs['weekend'] = ['sum', 'mean', 'min', 'max']
aggs['category_1'] = ['sum', 'mean', 'min', 'max']
aggs['authorized_flag'] = ['sum', 'mean', 'min', 'max']
#aggs['category_2'] = ['sum', 'mean', 'min', 'max']
#aggs['category_3'] = ['sum', 'mean', 'min', 'max']
aggs['card_id'] = ['size']
aggs['reference_date'] = ['median']

# %%
new_columns = create_new_columns('hist',aggs)
historical_trans_group_df = historical_trans_df.groupby('card_id').agg(aggs)
historical_trans_group_df.columns = new_columns
historical_trans_group_df.reset_index(drop=False,inplace=True)
historical_trans_group_df['hist_purchase_date_diff'] = (historical_trans_group_df['hist_purchase_date_max'] - historical_trans_group_df['hist_purchase_date_min']).dt.days
historical_trans_group_df['hist_purchase_date_average'] = historical_trans_group_df['hist_purchase_date_diff']/historical_trans_group_df['hist_card_id_size']
historical_trans_group_df['hist_purchase_date_uptonow'] = (datetime(2012,4,1) - historical_trans_group_df['hist_purchase_date_max']).dt.days
historical_trans_group_df['hist_purchase_date_uptomin'] = (datetime(2012,4,1) - historical_trans_group_df['hist_purchase_date_min']).dt.days
all_df = all_df.merge(historical_trans_group_df, on=['card_id'], how='left')

# %%
aggs = {}

for col in ['hour', 'weekofyear', 'dayofweek', 'year']:
    aggs[col] = ['nunique', 'mean', 'min', 'max']

    
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean', 'max', 'min', 'var']
aggs['weekend'] = ['sum', 'mean', 'min', 'max']
aggs['category_1'] = ['sum', 'mean', 'min', 'max']
#aggs['authorized_flag'] = ['sum', 'mean', 'min', 'max']
#aggs['category_2'] = ['sum', 'mean', 'min', 'max']
#aggs['category_3'] = ['sum', 'mean', 'min', 'max']
aggs['card_id'] = ['size']
aggs['reference_date'] = ['median']

# %%
new_columns = create_new_columns('new_hist',aggs)
new_merchant_trans_group_df = new_merchant_trans_df.groupby('card_id').agg(aggs)
new_merchant_trans_group_df.columns = new_columns
new_merchant_trans_group_df.reset_index(drop=False,inplace=True)
new_merchant_trans_group_df['new_hist_purchase_date_diff'] = (new_merchant_trans_group_df['new_hist_purchase_date_max'] - new_merchant_trans_group_df['new_hist_purchase_date_min']).dt.days
new_merchant_trans_group_df['new_hist_purchase_date_average'] = new_merchant_trans_group_df['new_hist_purchase_date_diff']/new_merchant_trans_group_df['new_hist_card_id_size']
new_merchant_trans_group_df['new_hist_purchase_date_uptonow'] = (datetime(2012,4,1) - new_merchant_trans_group_df['new_hist_purchase_date_max']).dt.days
new_merchant_trans_group_df['new_hist_purchase_date_uptomin'] = (datetime(2012,4,1) - new_merchant_trans_group_df['new_hist_purchase_date_min']).dt.days
#merge with train, test
all_df = all_df.merge(new_merchant_trans_group_df, on=['card_id'], how='left')

# %%
fill_new_hist_size = pd.read_csv('input/fill_new_hist_size_20190210_132027_cv3.397927.csv')
new_hist_card_id_size = pd.concat([all_df.loc[all_df['new_hist_card_id_size'].notnull(),['card_id','new_hist_card_id_size']],fill_new_hist_size])
all_df = all_df.merge(new_hist_card_id_size, on='card_id',how='left')
all_df['new_hist_card_id_size_x'] = all_df['new_hist_card_id_size_y']
del all_df['new_hist_card_id_size_y']
all_df.rename(columns={'new_hist_card_id_size_x':'new_hist_card_id_size'},inplace=True)

# %%
fill_new_hist_date_max = pd.read_csv('input/fill_new_hist_card_id_purchase_date_max_20190210_140257_cv12.776013.csv')
new_hist_purchase_date_max = pd.concat([all_df.loc[all_df['new_hist_purchase_date_max'].notnull(),['card_id','new_hist_purchase_date_max']],fill_new_hist_date_max])
all_df = all_df.merge(new_hist_purchase_date_max, on='card_id',how='left')
all_df['new_hist_purchase_date_max_x'] = all_df['new_hist_purchase_date_max_y']
del all_df['new_hist_purchase_date_max_y']
all_df.rename(columns={'new_hist_purchase_date_max_x':'new_hist_purchase_date_max'},inplace=True)

# %%
fill_new_hist_date_min = pd.read_csv('input/fill_new_hist_card_id_purchase_date_min_20190210_142523_cv11.764345.csv')
new_hist_purchase_date_min = pd.concat([all_df.loc[all_df['new_hist_purchase_date_min'].notnull(),['card_id','new_hist_purchase_date_min']],fill_new_hist_date_min])
all_df = all_df.merge(new_hist_purchase_date_min, on='card_id',how='left')
all_df['new_hist_purchase_date_min_x'] = all_df['new_hist_purchase_date_min_y']
del all_df['new_hist_purchase_date_min_y']
all_df.rename(columns={'new_hist_purchase_date_min_x':'new_hist_purchase_date_min'},inplace=True)

# %%
all_df['new_hist_purchase_date_min'] = pd.to_datetime(all_df['new_hist_purchase_date_min'])
all_df['new_hist_purchase_date_max'] = pd.to_datetime(all_df['new_hist_purchase_date_max'])

# %%
def get_train_default_prorcessing(df):
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['dayofyear'] = df['first_active_month'].dt.dayofyear
    df['quarter'] = df['first_active_month'].dt.quarter
    #df['is_month_start'] = df['first_active_month'].dt.is_month_start
    df['month'] = df['first_active_month'].dt.month
    df['year'] = df['first_active_month'].dt.year
    
    #df['elapsed_time'] = (datetime(2018, 2, 1).date() - df['first_active_month'].dt.date).dt.days
    df['elapsed_time'] = (datetime(2019,1, 20) - df['first_active_month']).dt.days
    #df['after_big_event'] = (datetime(2012,4, 1) - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['hist_last_buy'] = (df['hist_purchase_date_max'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_last_buy'] = (df['new_hist_purchase_date_max'] - df['first_active_month']).dt.days
    
    df['year_month'] = df['year']*100 + df['month']
    df['hist_diff_reference_date_first'] = 12*(df['hist_reference_date_median']//100 - df['year_month']//100) + (df['hist_reference_date_median']%100 - df['year_month']%100)
    df['hist_diff_reference_date_last'] = 12*(df['hist_purchase_date_max'].dt.year - df['year_month']//100) + (df['hist_purchase_date_max'].dt.month - df['year_month']%100)
    
    df['new_hist_diff_reference_date_first'] = 12*(df['new_hist_reference_date_median']//100 - df['year_month']//100) + (df['new_hist_reference_date_median']%100 - df['year_month']%100)
    df['new_hist_diff_reference_date_last'] = 12*(df['new_hist_purchase_date_max'].dt.year - df['year_month']//100) + (df['new_hist_purchase_date_max'].dt.month - df['year_month']%100)
    
    df['hist_diff_first_last'] = df['hist_diff_reference_date_first'] - df['hist_diff_reference_date_last'] 
    df['new_hist_diff_first_last'] = df['new_hist_diff_reference_date_first'] - df['new_hist_diff_reference_date_last'] 
    df['diff_new_hist_date_min_max'] = (df['new_hist_purchase_date_min'] - df['hist_purchase_date_max']).dt.days
    df['diff_new_hist_date_max_max'] = (df['new_hist_purchase_date_max'] - df['hist_purchase_date_max']).dt.days    
    
    
    df['hist_flag_ratio'] = df['hist_authorized_flag_sum'] / df['hist_card_id_size']
    #df['new_flag_ratio'] = df['new_hist_authorized_flag_sum'] / df['new_hist_card_id_size']
    #df['new_hist_flag_ratio'] = 1/(1+df['hist_flag_ratio'])
    
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['card_id_cnt_ratio'] = df['new_hist_card_id_size']/df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']
    df['purchase_amount_mean'] = df['new_hist_purchase_amount_mean']+df['hist_purchase_amount_mean']
    df['purchase_amount_max'] = df['new_hist_purchase_amount_max']+df['hist_purchase_amount_max']
    df['purchase_amount_min'] = df['new_hist_purchase_amount_min']+df['hist_purchase_amount_min']
    df['purchase_amount_ratio'] = df['new_hist_purchase_amount_sum']/df['hist_purchase_amount_sum']
    
    df['month_diff_mean'] = df['new_hist_month_diff_mean']+df['hist_month_diff_mean']
    df['month_diff_ratio'] = df['new_hist_month_diff_mean']/df['hist_month_diff_mean']
    df['month_lag_mean'] = df['new_hist_month_lag_mean']+df['hist_month_lag_mean']
    df['month_lag_max'] = df['new_hist_month_lag_max']+df['hist_month_lag_max']
    df['month_lag_min'] = df['new_hist_month_lag_min']+df['hist_month_lag_min']
    df['category_1_mean'] = df['new_hist_category_1_mean']+df['hist_category_1_mean']
    df['installments_total'] = df['new_hist_installments_sum']+df['hist_installments_sum']
    df['installments_mean'] = df['new_hist_installments_mean']+df['hist_installments_mean']
    df['installments_max'] = df['new_hist_installments_max']+df['hist_installments_max']
    df['installments_ratio'] = df['new_hist_installments_sum']/df['hist_installments_sum']
    df['price_total'] = df['purchase_amount_total'] / df['installments_total']
    df['price_mean'] = df['purchase_amount_mean'] / df['installments_mean']
    df['price_max'] = df['purchase_amount_max'] / df['installments_max']
    
    #df['duration_mean'] = df['new_hist_duration_mean']+df['hist_duration_mean']
    #df['duration_min'] = df['new_hist_duration_min']+df['hist_duration_min']
    #df['duration_max'] = df['new_hist_duration_max']+df['hist_duration_max']
    #df['amount_month_ratio_mean']=df['new_hist_amount_month_ratio_mean']+df['hist_amount_month_ratio_mean']
    #df['amount_month_ratio_min']=df['new_hist_amount_month_ratio_min']+df['hist_amount_month_ratio_min']
    #df['amount_month_ratio_max']=df['new_hist_amount_month_ratio_max']+df['hist_amount_month_ratio_max']
    df['new_CLV'] = df['new_hist_card_id_size'] * df['new_hist_purchase_amount_sum'] / df['new_hist_month_diff_mean']
    df['hist_CLV'] = df['hist_card_id_size'] * df['hist_purchase_amount_sum'] / df['hist_month_diff_mean']
    df['CLV_ratio'] = df['new_CLV'] / df['hist_CLV']
    
    del df['year']
    del df['year_month']
    del df['new_hist_reference_date_median']
    
    return df

# %%
all_df = get_train_default_prorcessing(all_df)

# %%
group_df = groupby_helper(new_merchant_trans_df,['card_id'], 'authorized_flag',['sum'],'new_hist')
all_df = all_df.merge(group_df, on=['card_id'], how='left')
all_df['new_flag_ratio'] = all_df['new_hist_card_id_authorized_flag_sum'] / all_df['new_hist_card_id_size']
all_df['new_hist_flag_ratio'] = all_df['new_flag_ratio']/(all_df['new_flag_ratio']+all_df['hist_flag_ratio'])
del all_df['new_hist_card_id_authorized_flag_sum']

# %%
all_df['feature123'] = all_df['feature_1'].astype(str) +'_'+all_df['feature_2'].astype(str)+'_'+all_df['feature_3'].astype(str)
all_df['feature123'] = pd.factorize(all_df['feature123'])[0]

# %%
group_df = groupby_helper(historical_trans_df,['card_id','month_lag'], 'subsector_id',['nunique'])
group_df['card_id_month_lag_subsector_id_nunique'] = group_df['card_id_month_lag_subsector_id_nunique']/(1-group_df['month_lag'])
del group_df['month_lag']

count_df = groupby_helper(group_df,['card_id'], 'card_id_month_lag_subsector_id_nunique',['sum','mean','std'])

all_df = all_df.merge(count_df, on=['card_id'], how='left')

# %%
group_df_mode = pd.read_csv('input/subsector_id_mode.csv')
group_df = groupby_helper(group_df_mode.reset_index(),'card_id', 'subsector_id',['nunique'],'mode')
all_df = all_df.merge(group_df, on=['card_id'], how='left')

# %%
group_df_mode_mci = pd.read_csv('input/merchant_category_id_mode.csv')
group_df = groupby_helper(group_df_mode_mci.reset_index(),'card_id', 'merchant_category_id',['nunique'],'mode')
all_df = all_df.merge(group_df, on=['card_id'], how='left')

# %%
all_df['feature123_frequency_encoding']= all_df['feature123'].map(all_df['feature123'].value_counts()/all_df.shape[0])

# %% [markdown]
# firstactive month보다 작거나 같은 달의 거래횟수 / 전체 거래횟수

# %%
historical_trans_df =historical_trans_df.merge(all_df[['card_id','first_active_month','target','feature123']], on='card_id',how='left')
historical_trans_df['ym'] = historical_trans_df['purchase_date'].dt.year*100 + historical_trans_df['purchase_date'].dt.month
historical_trans_df['first_active_month_ym'] = historical_trans_df['first_active_month'].dt.year*100 + historical_trans_df['first_active_month'].dt.month
historical_trans_df['is_smaller_firstactive'] = 0
historical_trans_df.loc[historical_trans_df['ym']<=historical_trans_df['first_active_month_ym'],'is_smaller_firstactive'] = 1
group_df = groupby_helper(historical_trans_df,'card_id', 'is_smaller_firstactive',['sum'])
temp = groupby_helper(historical_trans_df,'card_id', 'card_id',['size'])
group_df = group_df.merge(temp, on='card_id', how='left')
group_df['before_firstactive_purchase_ratio']=group_df['card_id_is_smaller_firstactive_sum'] /group_df['card_id_card_id_size']
all_df = all_df.merge(group_df[['card_id','before_firstactive_purchase_ratio']], on=['card_id'], how='left')

# %%
fill_new_hist_amount = pd.read_csv('input/fill_new_hist_purchase_amount_mean_20190210_153454_cv0.159328.csv')
new_hist_purchase_amount_mean = pd.concat([all_df.loc[all_df['new_hist_purchase_amount_mean'].notnull(),['card_id','new_hist_purchase_amount_mean']],fill_new_hist_amount])
all_df = all_df.merge(new_hist_purchase_amount_mean, on='card_id',how='left')
all_df['new_hist_purchase_amount_mean_x'] = all_df['new_hist_purchase_amount_mean_y']
del all_df['new_hist_purchase_amount_mean_y']
all_df.rename(columns={'new_hist_purchase_amount_mean_x':'new_hist_purchase_amount_mean'},inplace=True)

# %%
group_df = historical_trans_df.groupby(['card_id'])['month_lag'].unique().reset_index()
group_df['month_lag_last'] = group_df['month_lag'].apply(lambda x: x[-1])

group_df['month_lag_last2month'] =group_df['month_lag'].apply(lambda x: x[-2:])
group_df['month_lag_last2month'] = group_df['month_lag_last2month'].apply(lambda x: x[0])
group_df['month_lag_last3month'] =group_df['month_lag'].apply(lambda x: x[-3:])
group_df['month_lag_last3month'] = group_df['month_lag_last3month'].apply(lambda x: x[0])
historical_trans_df = historical_trans_df.merge(group_df, on='card_id', how='left')
del historical_trans_df['month_lag_y']
historical_trans_df.rename(columns={'month_lag_x':'month_lag'},inplace=True)

# %%
cat1_ratio = pd.read_csv('input/ratio_test.csv')
all_df = all_df.merge(cat1_ratio, on='card_id', how='left')

# %%
last_month = historical_trans_df.loc[(historical_trans_df['month_lag']==historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)&(historical_trans_df['category_1']==1)]
last_month_minus1 = historical_trans_df.loc[(historical_trans_df['month_lag']<historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]

prefix_1 = 'auth1_all_before_1month'
prefix_2 = 'auth1_cat1_1_last_1month'
group_df = groupby_helper(last_month_minus1,'card_id','purchase_amount',['mean','count','sum'],prefix_1)
temp = groupby_helper(last_month,'card_id','purchase_amount',['mean','count','sum'],prefix_2)
group_df = group_df.merge(temp, on='card_id', how='left')

group_df['{}_card_id_purchase_amount_mean_ratio'.format(prefix_2)] =   group_df['{}_card_id_purchase_amount_mean'.format(prefix_1)] /group_df['{}_card_id_purchase_amount_mean'.format(prefix_2)]
group_df['{}_card_id_purchase_amount_count_ratio'.format(prefix_2)] =  group_df['{}_card_id_purchase_amount_count'.format(prefix_1)]/group_df['{}_card_id_purchase_amount_count'.format(prefix_2)]
group_df['{}_card_id_purchase_amount_sum_ratio'.format(prefix_2)] =  group_df['{}_card_id_purchase_amount_sum'.format(prefix_1)]/group_df['{}_card_id_purchase_amount_sum'.format(prefix_2)]

del group_df['{}_card_id_purchase_amount_mean'.format(prefix_1)], group_df['{}_card_id_purchase_amount_count'.format(prefix_1)], group_df['{}_card_id_purchase_amount_sum'.format(prefix_1)]
all_df = all_df.merge(group_df, on='card_id', how='left')

# %%
last_month = historical_trans_df.loc[(historical_trans_df['month_lag']==historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]
last_month_minus1 = historical_trans_df.loc[(historical_trans_df['month_lag']<historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]

prefix_1 = 'auth1_cat1_1_all_before_1month'
prefix_2 = 'auth1_last_1month'
group_df = groupby_helper(last_month_minus1,'card_id','merchant_id',['nunique'],prefix_1)
temp = groupby_helper(last_month,'card_id','merchant_id',['nunique'],prefix_2)
group_df = group_df.merge(temp, on='card_id', how='left')

group_df['{}_card_id_merchant_id_nunique_ratio'.format(prefix_2)] =   group_df['{}_card_id_merchant_id_nunique'.format(prefix_1)] /group_df['{}_card_id_merchant_id_nunique'.format(prefix_2)]

all_df = all_df.merge(group_df, on='card_id', how='left')

# %%
last_month_purchase_amount_ratio3 = pd.read_csv('input/last_month_purchase_amount_ratio3.csv')
all_df = all_df.merge(last_month_purchase_amount_ratio3, on='card_id', how='left')

# %%
last_month_purchase_amount_ratio3 = pd.read_csv('input/last_month_purchase_amount_ratio.csv')
all_df = all_df.merge(last_month_purchase_amount_ratio3, on='card_id', how='left')

# %% [markdown]
# ## 아래 피쳐는 Test 용으로 사용하면 안됩니다.

# %%
last_month = historical_trans_df.loc[(historical_trans_df['month_lag']==historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]
last_month_minus1 = historical_trans_df.loc[(historical_trans_df['month_lag']<historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]

prefix_1 = 'auth1_cat1_1_all_before_1month'
prefix_2 = 'auth1_last_1month'
group_df = groupby_helper(last_month_minus1,'card_id','installments',['mean','count','sum'],prefix_1)
temp = groupby_helper(last_month,'card_id','installments',['mean','count','sum'],prefix_2)
group_df = group_df.merge(temp, on='card_id', how='left')

group_df['{}_card_id_installments_mean_ratio'.format(prefix_2)] =   group_df['{}_card_id_installments_mean'.format(prefix_1)] /group_df['{}_card_id_installments_mean'.format(prefix_2)]
group_df['{}_card_id_installments_count_ratio'.format(prefix_2)] =  group_df['{}_card_id_installments_count'.format(prefix_1)]/group_df['{}_card_id_installments_count'.format(prefix_2)]
group_df['{}_card_id_installments_sum_ratio'.format(prefix_2)] =  group_df['{}_card_id_installments_sum'.format(prefix_1)]/group_df['{}_card_id_installments_sum'.format(prefix_2)]

del group_df['{}_card_id_installments_mean'.format(prefix_1)], group_df['{}_card_id_installments_count'.format(prefix_1)], group_df['{}_card_id_installments_sum'.format(prefix_1)]
all_df = all_df.merge(group_df, on='card_id', how='left')
# Out:
# card_id installments ['mean', 'count', 'sum']
# card_id installments ['mean', 'count', 'sum']

# %%
last_month = historical_trans_df.loc[(historical_trans_df['month_lag']==historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]
last_month_minus1 = historical_trans_df.loc[(historical_trans_df['month_lag']<historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]

prefix_1 = 'auth1_cat1_1_all_before_1month'
prefix_2 = 'auth1_last_1month'
col = 'city_id'
group_df = groupby_helper(last_month_minus1,'card_id',col,['nunique'],prefix_1)
temp = groupby_helper(last_month,'card_id',col,['nunique'],prefix_2)
group_df = group_df.merge(temp, on='card_id', how='left')

group_df['{}_card_id_{}_nunique_ratio'.format(prefix_2,col)] =   group_df['{}_card_id_{}_nunique'.format(prefix_1,col)] /group_df['{}_card_id_{}_nunique'.format(prefix_2,col)]

all_df = all_df.merge(group_df, on='card_id', how='left')
# Out:
# card_id city_id ['nunique']
# card_id city_id ['nunique']

# %%
last_month = historical_trans_df.loc[(historical_trans_df['month_lag']==historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]
last_month_minus1 = historical_trans_df.loc[(historical_trans_df['month_lag']<historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]

prefix_1 = 'auth1_cat1_1_all_before_1month'
prefix_2 = 'auth1_last_1month'
col = 'merchant_category_id'
group_df = groupby_helper(last_month_minus1,'card_id',col,['nunique'],prefix_1)
temp = groupby_helper(last_month,'card_id',col,['nunique'],prefix_2)
group_df = group_df.merge(temp, on='card_id', how='left')

group_df['{}_card_id_{}_nunique_ratio'.format(prefix_2,col)] =   group_df['{}_card_id_{}_nunique'.format(prefix_1,col)] /group_df['{}_card_id_{}_nunique'.format(prefix_2,col)]
#group_df['{}_card_id_{}_max_ratio'.format(prefix_2,col)] =  group_df['{}_card_id_{}_max'.format(prefix_1,col)]/group_df['{}_card_id_{}_max'.format(prefix_2,col)]
#group_df['{}_card_id_{}_min_ratio'.format(prefix_2,col)] =  group_df['{}_card_id_{}_min'.format(prefix_1,col)]/group_df['{}_card_id_{}_min'.format(prefix_2,col)]

#del group_df['{}_card_id_{}_nunique'.format(prefix_1,col)]#, group_df['{}_card_id_{}_max'.format(prefix_1,col)], group_df['{}_card_id_{}_min'.format(prefix_1,col)]
all_df = all_df.merge(group_df, on='card_id', how='left')
# Out:
# card_id merchant_category_id ['nunique']
# card_id merchant_category_id ['nunique']

# %%
last_month = historical_trans_df.loc[(historical_trans_df['month_lag']==historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]
last_month_minus1 = historical_trans_df.loc[(historical_trans_df['month_lag']<historical_trans_df['month_lag_last'])&(historical_trans_df['authorized_flag']==1)]

prefix_1 = 'auth1_cat1_1_all_before_1month'
prefix_2 = 'auth1_last_1month'
col = 'subsector_id'
group_df = groupby_helper(last_month_minus1,'card_id',col,['nunique'],prefix_1)
temp = groupby_helper(last_month,'card_id',col,['nunique'],prefix_2)
group_df = group_df.merge(temp, on='card_id', how='left')

group_df['{}_card_id_{}_nunique_ratio'.format(prefix_2,col)] =   group_df['{}_card_id_{}_nunique'.format(prefix_1,col)] /group_df['{}_card_id_{}_nunique'.format(prefix_2,col)]
#group_df['{}_card_id_{}_max_ratio'.format(prefix_2,col)] =  group_df['{}_card_id_{}_max'.format(prefix_1,col)]/group_df['{}_card_id_{}_max'.format(prefix_2,col)]
#group_df['{}_card_id_{}_min_ratio'.format(prefix_2,col)] =  group_df['{}_card_id_{}_min'.format(prefix_1,col)]/group_df['{}_card_id_{}_min'.format(prefix_2,col)]

#del group_df['{}_card_id_{}_nunique'.format(prefix_1,col)]#, group_df['{}_card_id_{}_max'.format(prefix_1,col)], group_df['{}_card_id_{}_min'.format(prefix_1,col)]
all_df = all_df.merge(group_df, on='card_id', how='left')
# Out:
# card_id subsector_id ['nunique']
# card_id subsector_id ['nunique']

# %%
last_month = historical_trans_df.loc[(historical_trans_df['authorized_flag']==1)]
new_merchant_trans_df_cat11 = new_merchant_trans_df.loc[new_merchant_trans_df['category_1']==1]
prefix_1 = 'new_hist'
prefix_2 = 'auth1_cat1_1_all_by_new_hist'
col = 'purchase_amount'
group_df = groupby_helper(new_merchant_trans_df_cat11,'card_id',col,['mean','count','sum'],prefix_1)
temp = groupby_helper(last_month,'card_id',col,['mean','count','sum'],prefix_2)
group_df = group_df.merge(temp, on='card_id', how='left')

group_df['{}_card_id_{}_mean_ratio'.format(prefix_2,col)] =   group_df['{}_card_id_{}_mean'.format(prefix_1,col)] /group_df['{}_card_id_{}_mean'.format(prefix_2,col)]
group_df['{}_card_id_{}_count_ratio'.format(prefix_2,col)] =  group_df['{}_card_id_{}_count'.format(prefix_1,col)]/group_df['{}_card_id_{}_count'.format(prefix_2,col)]
group_df['{}_card_id_{}_sum_ratio'.format(prefix_2,col)] =  group_df['{}_card_id_{}_sum'.format(prefix_1,col)]/group_df['{}_card_id_{}_sum'.format(prefix_2,col)]


all_df = all_df.merge(group_df[['card_id',
                                '{}_card_id_{}_mean_ratio'.format(prefix_2,col),
                               '{}_card_id_{}_count_ratio'.format(prefix_2,col),
                              '{}_card_id_{}_sum_ratio'.format(prefix_2,col) ]], on='card_id', how='left')
# Out:
# card_id purchase_amount ['mean', 'count', 'sum']
# card_id purchase_amount ['mean', 'count', 'sum']

# %%
historical_trans_df.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'category_3', 'merchant_category_id', 'merchant_id', 'month_lag',
#        'purchase_amount', 'purchase_date', 'category_2', 'state_id',
#        'subsector_id', 'year', 'weekofyear', 'month', 'dayofweek', 'weekend',
#        'hour', 'month_diff', 'reference_date', 'installments_999',
#        'first_active_month', 'target', 'feature123', 'ym',
#        'first_active_month_ym', 'is_smaller_firstactive', 'month_lag_last',
#        'month_lag_last2month', 'month_lag_last3month'],
#       dtype='object')

# %% [markdown]
# # Single Model

# %%
for col in all_df.columns:
    if col.find('weekend') !=-1:
        print(col)
        del all_df[col]
# Out:
# hist_weekend_sum
# hist_weekend_mean
# hist_weekend_min
# hist_weekend_max
# new_hist_weekend_sum
# new_hist_weekend_mean
# new_hist_weekend_min
# new_hist_weekend_max

# %%
for col in all_df.columns:
    if all_df[col].nunique() == 1:
        print(col)
        del all_df[col]
# Out:
# hist_year_min
# hist_authorized_flag_max
# new_flag_ratio

# %%
for col in all_df.columns:
    if col in ['new_hist_year_max', 'hist_year_max', 'hist_authorized_flag_min',
       'new_hist_year_min','new_hist_diff_first_last', 'hist_category_1_min',
       'new_hist_category_1_max', 'hist_category_1_max',]:
        print(col)
        del all_df[col]
# Out:
# auth1_cat1_1_all_by_new_hist_card_id_purchase_amount_mean_ratio
# auth1_cat1_1_all_by_new_hist_card_id_purchase_amount_count_ratio
# auth1_cat1_1_all_by_new_hist_card_id_purchase_amount_sum_ratio

# %% [markdown]
# 아래 코드는 사용하면 안됨

# %%
for col in all_df.columns:
    if col.find('cat1_before_two_month_card_id_purchase_amount_') !=-1:
        print(col)
        del all_df[col]
# Out:
# cat1_before_two_month_card_id_purchase_amount_mean
# cat1_before_two_month_card_id_purchase_amount_count
# cat1_before_two_month_card_id_purchase_amount_sum

# %%
print(all_df.shape)
train_df = all_df.loc[all_df['target'].notnull()]
test_df = all_df.loc[all_df['target'].isnull()]

print(train_df.shape)
print(test_df.shape)
#train_df['target'] = np.power(2,train_df['target'])-1e-10

train_df['outliers'] = 0
train_df.loc[train_df['target'] < -30, 'outliers'] = 1

for f in ['feature_1','feature_2','feature_3']:
    order_label = train_df.groupby([f])['outliers'].mean()
    train_df[f] = train_df[f].map(order_label)
    test_df[f] = test_df[f].map(order_label)

group_df = groupby_helper(train_df,['dayofyear'], 'outliers',['mean'])
train_df = train_df.merge(group_df, on=['dayofyear'], how='left')
test_df = test_df.merge(group_df, on=['dayofyear'], how='left')

group_df = groupby_helper(train_df,['elapsed_time'], 'outliers',['mean'])
train_df = train_df.merge(group_df, on=['elapsed_time'], how='left')
test_df = test_df.merge(group_df, on=['elapsed_time'], how='left')

train_columns = [c for c in train_df.columns if c not in ['card_id', 'first_active_month','target','outliers',]]
train_columns
# Out:
# (325540, 206)
# (201917, 206)
# (123623, 206)
# ['dayofyear'] outliers ['mean']
# ['elapsed_time'] outliers ['mean']
# ['feature_1',
#  'feature_2',
#  'feature_3',
#  'card_id_card_id_month_lag_purchase_amount_count_sum',
#  'card_id_card_id_month_lag_purchase_amount_count_mean',
#  'card_id_card_id_month_lag_purchase_amount_count_std',
#  'card_id_card_id_month_lag_purchase_amount_mean_sum',
#  'card_id_card_id_month_lag_purchase_amount_mean_mean',
#  'card_id_card_id_month_lag_purchase_amount_mean_std',
#  'auth_0_card_id_month_nunique',
#  'auth_0_card_id_month_max',
#  'auth_0_card_id_month_min',
#  'auth_0_card_id_month_mean',
#  'auth_0_card_id_month_std',
#  'auth_1_card_id_month_nunique',
#  'auth_1_card_id_month_max',
#  'auth_1_card_id_month_min',
#  'auth_1_card_id_month_mean',
#  'auth_1_card_id_month_std',
#  'new_hist_card_id_month_nunique',
#  'new_hist_card_id_month_max',
#  'new_hist_card_id_month_min',
#  'new_hist_card_id_month_mean',
#  'card_id_merchant_id_nunique',
#  'auth_0_card_id_merchant_category_id_nunique',
#  'auth_1_card_id_merchant_category_id_nunique',
#  'auth_0_card_id_subsector_id_nunique',
#  'auth_1_card_id_subsector_id_nunique',
#  'auth_0_card_id_state_id_nunique',
#  'auth_1_card_id_state_id_nunique',
#  'card_id_city_id_nunique',
#  'new_hist_card_id_merchant_category_id_nunique',
#  'new_hist_card_id_subsector_id_nunique',
#  'new_hist_card_id_state_id_nunique',
#  'hist_hour_nunique',
#  'hist_hour_mean',
#  'hist_hour_min',
#  'hist_hour_max',
#  'hist_weekofyear_nunique',
#  'hist_weekofyear_mean',
#  'hist_weekofyear_min',
#  'hist_weekofyear_max',
#  'hist_dayofweek_nunique',
#  'hist_dayofweek_mean',
#  'hist_dayofweek_min',
#  'hist_dayofweek_max',
#  'hist_year_nunique',
#  'hist_year_mean',
#  'hist_purchase_amount_sum',
#  'hist_purchase_amount_max',
#  'hist_purchase_amount_min',
#  'hist_purchase_amount_mean',
#  'hist_purchase_amount_var',
#  'hist_installments_sum',
#  'hist_installments_max',
#  'hist_installments_min',
#  'hist_installments_mean',
#  'hist_installments_var',
#  'hist_purchase_date_max',
#  'hist_purchase_date_min',
#  'hist_month_lag_max',
#  'hist_month_lag_min',
#  'hist_month_lag_mean',
#  'hist_month_lag_var',
#  'hist_month_diff_mean',
#  'hist_month_diff_max',
#  'hist_month_diff_min',
#  'hist_month_diff_var',
#  'hist_category_1_sum',
#  'hist_category_1_mean',
#  'hist_authorized_flag_sum',
#  'hist_authorized_flag_mean',
#  'hist_card_id_size',
#  'hist_reference_date_median',
#  'hist_purchase_date_diff',
#  'hist_purchase_date_average',
#  'hist_purchase_date_uptonow',
#  'hist_purchase_date_uptomin',
#  'new_hist_hour_nunique',
#  'new_hist_hour_mean',
#  'new_hist_hour_min',
#  'new_hist_hour_max',
#  'new_hist_weekofyear_nunique',
#  'new_hist_weekofyear_mean',
#  'new_hist_weekofyear_min',
#  'new_hist_weekofyear_max',
#  'new_hist_dayofweek_nunique',
#  'new_hist_dayofweek_mean',
#  'new_hist_dayofweek_min',
#  'new_hist_dayofweek_max',
#  'new_hist_year_nunique',
#  'new_hist_year_mean',
#  'new_hist_purchase_amount_sum',
#  'new_hist_purchase_amount_max',
#  'new_hist_purchase_amount_min',
#  'new_hist_purchase_amount_mean',
#  'new_hist_purchase_amount_var',
#  'new_hist_installments_sum',
#  'new_hist_installments_max',
#  'new_hist_installments_min',
#  'new_hist_installments_mean',
#  'new_hist_installments_var',
#  'new_hist_purchase_date_max',
#  'new_hist_purchase_date_min',
#  'new_hist_month_lag_max',
#  'new_hist_month_lag_min',
#  'new_hist_month_lag_mean',
#  'new_hist_month_lag_var',
#  'new_hist_month_diff_mean',
#  'new_hist_month_diff_max',
#  'new_hist_month_diff_min',
#  'new_hist_month_diff_var',
#  'new_hist_category_1_sum',
#  'new_hist_category_1_mean',
#  'new_hist_category_1_min',
#  'new_hist_card_id_size',
#  'new_hist_purchase_date_diff',
#  'new_hist_purchase_date_average',
#  'new_hist_purchase_date_uptonow',
#  'new_hist_purchase_date_uptomin',
#  'dayofweek',
#  'weekofyear',
#  'dayofyear',
#  'quarter',
#  'month',
#  'elapsed_time',
#  'hist_first_buy',
#  'hist_last_buy',
#  'new_hist_first_buy',
#  'new_hist_last_buy',
#  'hist_diff_reference_date_first',
#  'hist_diff_reference_date_last',
#  'new_hist_diff_reference_date_first',
#  'new_hist_diff_reference_date_last',
#  'hist_diff_first_last',
#  'diff_new_hist_date_min_max',
#  'diff_new_hist_date_max_max',
#  'hist_flag_ratio',
#  'card_id_total',
#  'card_id_cnt_ratio',
#  'purchase_amount_total',
#  'purchase_amount_mean',
#  'purchase_amount_max',
#  'purchase_amount_min',
#  'purchase_amount_ratio',
#  'month_diff_mean',
#  'month_diff_ratio',
#  'month_lag_mean',
#  'month_lag_max',
#  'month_lag_min',
#  'category_1_mean',
#  'installments_total',
#  'installments_mean',
#  'installments_max',
#  'installments_ratio',
#  'price_total',
#  'price_mean',
#  'price_max',
#  'new_CLV',
#  'hist_CLV',
#  'CLV_ratio',
#  'new_hist_flag_ratio',
#  'feature123',
#  'card_id_card_id_month_lag_subsector_id_nunique_sum',
#  'card_id_card_id_month_lag_subsector_id_nunique_mean',
#  'card_id_card_id_month_lag_subsector_id_nunique_std',
#  'mode_card_id_subsector_id_nunique',
#  'mode_card_id_merchant_category_id_nunique',
#  'feature123_frequency_encoding',
#  'before_firstactive_purchase_ratio',
#  'auth1_cat1_last_month_card_id_purchase_amount_mean',
#  'auth1_cat1_last_month_card_id_purchase_amount_count',
#  'auth1_cat1_last_month_card_id_purchase_amount_sum',
#  'auth1_cat1_last_month_card_id_purchase_amount_mean_ratio',
#  'auth1_cat1_last_month_card_id_purchase_amount_count_ratio',
#  'auth1_cat1_last_month_card_id_purchase_amount_sum_ratio',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_mean',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_count',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_sum',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_mean_ratio',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_count_ratio',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_sum_ratio',
#  'auth1_cat1_1_all_before_1month_card_id_merchant_id_nunique',
#  'auth1_last_1month_card_id_merchant_id_nunique',
#  'auth1_last_1month_card_id_merchant_id_nunique_ratio',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_min',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_max',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_sum',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_mean',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_std',
#  'last_month_purchase_amount_ratio',
#  'auth1_last_1month_card_id_installments_mean',
#  'auth1_last_1month_card_id_installments_count',
#  'auth1_last_1month_card_id_installments_sum',
#  'auth1_last_1month_card_id_installments_mean_ratio',
#  'auth1_last_1month_card_id_installments_count_ratio',
#  'auth1_last_1month_card_id_installments_sum_ratio',
#  'auth1_cat1_1_all_before_1month_card_id_city_id_nunique',
#  'auth1_last_1month_card_id_city_id_nunique',
#  'auth1_last_1month_card_id_city_id_nunique_ratio',
#  'auth1_cat1_1_all_before_1month_card_id_merchant_category_id_nunique',
#  'auth1_last_1month_card_id_merchant_category_id_nunique',
#  'auth1_last_1month_card_id_merchant_category_id_nunique_ratio',
#  'dayofyear_outliers_mean',
#  'elapsed_time_outliers_mean']

# %%
train = train_df.copy()
target = train['target']
del train['target']

# %%
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.015,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 24,
         "seed": 6}

#prepare fit model with cross-validation
np.random.seed(2019)

feature_importance_df = pd.DataFrame()
folds = StratifiedKFold(n_splits=9, shuffle=True, random_state=4950)
oof = np.zeros(len(train))
predictions = np.zeros(len(test_df))
cv_score_list = []
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, train['outliers'].values)):
    strLog = "fold {}".format(fold_+1)
    print(strLog)
    trn_data = lgb.Dataset(train.iloc[trn_idx][train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 100)
    oof[val_idx] = clf.predict(train.iloc[val_idx][train_columns], num_iteration=clf.best_iteration)
    
    cv_score = np.sqrt(mean_squared_error(oof[val_idx], target.iloc[val_idx]))
    cv_score_list.append(cv_score)
    #feature importance
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    #predictions
    predictions += clf.predict(test_df[train_columns], num_iteration=clf.best_iteration) / folds.n_splits

cv_score = np.sqrt(mean_squared_error(oof, target))
print(cv_score)
print(cv_score_list)
print(np.std(cv_score_list))
withoutoutlier_predictions = predictions.copy()
# Out:
# fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.60233	valid_1's rmse: 3.68647
# [200]	training's rmse: 3.51247	valid_1's rmse: 3.66446
# [300]	training's rmse: 3.4531	valid_1's rmse: 3.6579
# [400]	training's rmse: 3.40998	valid_1's rmse: 3.65567
# [500]	training's rmse: 3.37311	valid_1's rmse: 3.65457
# [600]	training's rmse: 3.34176	valid_1's rmse: 3.6526
# [700]	training's rmse: 3.31412	valid_1's rmse: 3.65265
# [800]	training's rmse: 3.28666	valid_1's rmse: 3.65177
# [900]	training's rmse: 3.26052	valid_1's rmse: 3.65169
# Early stopping, best iteration is:
# [856]	training's rmse: 3.27121	valid_1's rmse: 3.65087
# fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.59873	valid_1's rmse: 3.70589
# [200]	training's rmse: 3.50718	valid_1's rmse: 3.68148
# [300]	training's rmse: 3.45095	valid_1's rmse: 3.67368
# [400]	training's rmse: 3.40711	valid_1's rmse: 3.66974
# [500]	training's rmse: 3.37165	valid_1's rmse: 3.66782
# [600]	training's rmse: 3.34012	valid_1's rmse: 3.66563
# [700]	training's rmse: 3.3111	valid_1's rmse: 3.66554
# [800]	training's rmse: 3.28393	valid_1's rmse: 3.66526
# Early stopping, best iteration is:
# [763]	training's rmse: 3.29462	valid_1's rmse: 3.66432
# fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.60198	valid_1's rmse: 3.68851
# [200]	training's rmse: 3.51059	valid_1's rmse: 3.66394
# [300]	training's rmse: 3.45353	valid_1's rmse: 3.6515
# [400]	training's rmse: 3.41093	valid_1's rmse: 3.64551
# [500]	training's rmse: 3.3738	valid_1's rmse: 3.64131
# [600]	training's rmse: 3.34189	valid_1's rmse: 3.63846
# [700]	training's rmse: 3.3144	valid_1's rmse: 3.63631
# [800]	training's rmse: 3.2881	valid_1's rmse: 3.63474
# [900]	training's rmse: 3.26226	valid_1's rmse: 3.63398
# [1000]	training's rmse: 3.23914	valid_1's rmse: 3.6326
# [1100]	training's rmse: 3.21478	valid_1's rmse: 3.63206
# Early stopping, best iteration is:
# [1073]	training's rmse: 3.22134	valid_1's rmse: 3.63166
# fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.60442	valid_1's rmse: 3.66342
# [200]	training's rmse: 3.51571	valid_1's rmse: 3.63304
# [300]	training's rmse: 3.45972	valid_1's rmse: 3.62076
# [400]	training's rmse: 3.41731	valid_1's rmse: 3.61448
# [500]	training's rmse: 3.38063	valid_1's rmse: 3.6113
# [600]	training's rmse: 3.34906	valid_1's rmse: 3.60804
# [700]	training's rmse: 3.32048	valid_1's rmse: 3.60725
# [800]	training's rmse: 3.29319	valid_1's rmse: 3.60608
# [900]	training's rmse: 3.26842	valid_1's rmse: 3.60582
# [1000]	training's rmse: 3.24497	valid_1's rmse: 3.60545
# Early stopping, best iteration is:
# [981]	training's rmse: 3.24904	valid_1's rmse: 3.60501
# fold 5
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.59872	valid_1's rmse: 3.70795
# [200]	training's rmse: 3.50899	valid_1's rmse: 3.68928
# [300]	training's rmse: 3.4505	valid_1's rmse: 3.68216
# [400]	training's rmse: 3.40569	valid_1's rmse: 3.67912
# [500]	training's rmse: 3.36928	valid_1's rmse: 3.67851
# [600]	training's rmse: 3.33701	valid_1's rmse: 3.67795
# [700]	training's rmse: 3.30804	valid_1's rmse: 3.67803
# Early stopping, best iteration is:
# [616]	training's rmse: 3.33204	valid_1's rmse: 3.67757
# fold 6
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.60847	valid_1's rmse: 3.65928
# [200]	training's rmse: 3.52047	valid_1's rmse: 3.62296
# [300]	training's rmse: 3.46425	valid_1's rmse: 3.60781
# [400]	training's rmse: 3.42143	valid_1's rmse: 3.60196
# [500]	training's rmse: 3.38423	valid_1's rmse: 3.59935
# [600]	training's rmse: 3.35262	valid_1's rmse: 3.59651
# [700]	training's rmse: 3.32479	valid_1's rmse: 3.59577
# [800]	training's rmse: 3.29813	valid_1's rmse: 3.59507
# [900]	training's rmse: 3.27317	valid_1's rmse: 3.5956
# Early stopping, best iteration is:
# [813]	training's rmse: 3.29455	valid_1's rmse: 3.59473
# fold 7
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.59994	valid_1's rmse: 3.70519
# [200]	training's rmse: 3.51122	valid_1's rmse: 3.67885
# [300]	training's rmse: 3.45456	valid_1's rmse: 3.66676
# [400]	training's rmse: 3.41362	valid_1's rmse: 3.6596
# [500]	training's rmse: 3.37831	valid_1's rmse: 3.6553
# [600]	training's rmse: 3.34669	valid_1's rmse: 3.65341
# [700]	training's rmse: 3.31856	valid_1's rmse: 3.65094
# [800]	training's rmse: 3.29124	valid_1's rmse: 3.64967
# [900]	training's rmse: 3.26764	valid_1's rmse: 3.64871
# [1000]	training's rmse: 3.24477	valid_1's rmse: 3.64876
# [1100]	training's rmse: 3.22222	valid_1's rmse: 3.64786
# [1200]	training's rmse: 3.19943	valid_1's rmse: 3.64768
# [1300]	training's rmse: 3.17778	valid_1's rmse: 3.64781
# Early stopping, best iteration is:
# [1224]	training's rmse: 3.19443	valid_1's rmse: 3.64733
# fold 8
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.60692	valid_1's rmse: 3.67232
# [200]	training's rmse: 3.51747	valid_1's rmse: 3.63782
# [300]	training's rmse: 3.46135	valid_1's rmse: 3.62374
# [400]	training's rmse: 3.41798	valid_1's rmse: 3.61628
# [500]	training's rmse: 3.38187	valid_1's rmse: 3.61231
# [600]	training's rmse: 3.3502	valid_1's rmse: 3.60954
# [700]	training's rmse: 3.32158	valid_1's rmse: 3.60786
# [800]	training's rmse: 3.29517	valid_1's rmse: 3.60716
# [900]	training's rmse: 3.26934	valid_1's rmse: 3.6057
# [1000]	training's rmse: 3.24578	valid_1's rmse: 3.60459
# [1100]	training's rmse: 3.22221	valid_1's rmse: 3.60425
# Early stopping, best iteration is:
# [1025]	training's rmse: 3.23966	valid_1's rmse: 3.60416
# fold 9
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.59717	valid_1's rmse: 3.70833
# [200]	training's rmse: 3.50652	valid_1's rmse: 3.69051
# [300]	training's rmse: 3.44571	valid_1's rmse: 3.68091
# [400]	training's rmse: 3.40124	valid_1's rmse: 3.67454
# [500]	training's rmse: 3.36605	valid_1's rmse: 3.67216
# [600]	training's rmse: 3.33426	valid_1's rmse: 3.67146
# [700]	training's rmse: 3.30461	valid_1's rmse: 3.67039
# [800]	training's rmse: 3.27657	valid_1's rmse: 3.67016
# Early stopping, best iteration is:
# [723]	training's rmse: 3.29771	valid_1's rmse: 3.66939
# 3.638454298444785
# [3.650866222579616, 3.6643239110714534, 3.631655629119661, 3.60501045005935, 3.677572534277392, 3.594729839853449, 3.6473297271878082, 3.6041559368257077, 3.6693924983797723]
# 0.02914002665179368

# %% [markdown]
# 3.638454298444785
# [3.650866222579616, 3.6643239110714534, 3.631655629119661, 3.60501045005935, 3.677572534277392, 3.594729839853449, 3.6473297271878082, 3.6041559368257077, 3.6693924983797723]
# 0.02914002665179368
#
# 3.639846310816912
# [3.650877672981584, 3.6596110537417688, 3.6331717252546745, 3.6112881112378767, 3.679582136191987, 3.5940232396736285, 3.648333731974855, 3.6094343777659503, 3.6713264271798214]
# 0.027966174151551004
#
# 3.6394442072674127
# [3.645926788562734, 3.6699519965030594, 3.6362552785456703, 3.610536613451775, 3.6765978124327376, 3.5931566371041845, 3.6466409315481987, 3.6084064557353304, 3.6665494646956835]
# 0.028069795674465995
#
# 3.6402528910979655
# [3.648117534209358, 3.6704248426158577, 3.634663384962872, 3.607532911481209, 3.6778216590556925, 3.59122163131638, 3.6492897131291477, 3.612366202855478, 3.669789634363325]
# 0.02909972176444201
#
# 3.6402538293226727
# [3.640925550390848, 3.671503771238856, 3.632340290393655, 3.6166026218812477, 3.6788477052880273, 3.589571256542526, 3.6523497083618515, 3.6138682813552006, 3.665294963202596]
# 0.02813989511531963
#
# 3.6405307468865984
# [3.6455820900379687, 3.666180022374183, 3.6349562435972667, 3.613217296402693, 3.681676799693321, 3.5959030909405985, 3.6476911094231648, 3.6149825458283398, 3.66370903435235]
# 0.026638015923934003
#
# 3.64054513631046
# [3.6420366804360835, 3.658131395819552, 3.6351811283450814, 3.6150760914027504, 3.6860387441461415, 3.5969102761098375, 3.6499975591115166, 3.613854499727182, 3.6667926915110134]
# 0.02677727170086975
#
# 3.642949234454408
# [3.650372093530145, 3.6654924308558225, 3.6363536724363317, 3.6116579841044336, 3.683739370140129, 3.599946129541865, 3.6482507919569693, 3.6219036348081093, 3.6679752038284614]
# 0.026238823717363524
# <br><br>
# 3.6428863718087587
# [3.6522792332250327, 3.665450676045149, 3.636531749195274, 3.6140651658687664, 3.6852817839701943, 3.5979954896074053, 3.646315507786246, 3.619488332145068, 3.667682002994765]
# 0.026780884869751578
#
#
# 3.6428146664055
# [3.6501135678910366, 3.664859009681865, 3.63493765968693, 3.6128540227141923, 3.685697657686427, 3.5996142490993166, 3.649337560843338, 3.6153675492689836, 3.671612040623591]
# 0.02754637440509606
#
# 3.642503843704918
# [3.64757341534984, 3.663428698392028, 3.63447519800449, 3.616714271030949, 3.681904119176495, 3.6010349183991646, 3.6494781818376794, 3.6139121267497876, 3.6731517506764777]
# 0.02639550490504317
#
# 3.6425160908510565
# [3.6488564856876575, 3.6688472934843923, 3.631136078642995, 3.6085547967228577, 3.6870112040323146, 3.6007539214264095, 3.651298834208597, 3.6150517267893227, 3.6701262870971574]
# 0.028546139610707896
#
# 3.642831909409755
# [3.6483118994300394, 3.668117392778045, 3.637584552007164, 3.614629343104113, 3.6835262056884464, 3.595595704820776, 3.6523621200675214, 3.6181163473641895, 3.6663317549971293]
# 0.027148612642736943

# %%
filename = '{}_cv{:.6f}'.format(datetime.now().strftime('%Y%m%d_%H%M%S'), cv_score)

cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)
best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,26))
sns.barplot(x="importance", y="Feature", data=best_features.sort_values(by="importance",ascending=False))
plt.title('LightGBM Features (averaged over folds)')
plt.tight_layout()
plt.savefig('fi/{}_lgbm_importances.png'.format(filename))

# %%
feature_importance_df.groupby('Feature')['importance'].sum().reset_index().sort_values('importance')
# Out:
#                                                Feature  importance
# 86                                hist_diff_first_last           5
# 150                            new_hist_category_1_min           8
# 170                            new_hist_month_diff_max          10
# 193                                 new_hist_year_mean          10
# 172                            new_hist_month_diff_min          14
# 203                                            quarter          15
# 126                                  hist_year_nunique          16
# 84                                  hist_dayofweek_min          18
# 145                     new_hist_card_id_month_nunique          30
# 134                                              month          38
# 176                             new_hist_month_lag_min          39
# 120                         hist_reference_date_median          46
# 105                                 hist_month_lag_max          69
# 155                         new_hist_dayofweek_nunique         114
# 75                                           feature_3         116
# 85                              hist_dayofweek_nunique         121
# 194                              new_hist_year_nunique         129
# 174                             new_hist_month_lag_max         132
# 192                        new_hist_weekofyear_nunique         180
# 39                            auth_1_card_id_month_min         187
# 82                                  hist_dayofweek_max         188
# 37                            auth_1_card_id_month_max         195
# 107                                 hist_month_lag_min         198
# 87                      hist_diff_reference_date_first         220
# 88                       hist_diff_reference_date_last         245
# 91                                       hist_hour_max         252
# 97                               hist_installments_min         253
# 163                              new_hist_hour_nunique         253
# 147                  new_hist_card_id_state_id_nunique         256
# 139                                      month_lag_min         264
# 103                                hist_month_diff_min         276
# 137                                      month_lag_max         276
# 152                             new_hist_dayofweek_max         298
# 171                           new_hist_month_diff_mean         301
# 127                                   installments_max         321
# 95                               hist_installments_max         321
# 154                             new_hist_dayofweek_min         333
# 16           auth1_last_1month_card_id_city_id_nunique         345
# 167                          new_hist_installments_sum         355
# 90                                     hist_flag_ratio         359
# 164                          new_hist_installments_max         364
# 157                  new_hist_diff_reference_date_last         378
# 24   auth1_last_1month_card_id_merchant_category_id...         384
# 18        auth1_last_1month_card_id_installments_count         394
# 148              new_hist_card_id_subsector_id_nunique         412
# 42                     auth_1_card_id_state_id_nunique         419
# 173                            new_hist_month_diff_var         423
# 144                         new_hist_card_id_month_min         426
# 166                          new_hist_installments_min         455
# 4    auth1_cat1_1_last_1month_card_id_purchase_amou...         470
# 156                 new_hist_diff_reference_date_first         477
# 74                                           feature_2         485
# 69                                        elapsed_time         488
# 79                                   hist_card_id_size         497
# 31                            auth_0_card_id_month_min         500
# 54                             card_id_city_id_nunique         520
# 64                                           dayofweek         523
# 125                                     hist_year_mean         527
# 26       auth1_last_1month_card_id_merchant_id_nunique         541
# 29                            auth_0_card_id_month_max         544
# 118                         hist_purchase_date_uptomin         555
# 62                                       card_id_total         560
# 93                                       hist_hour_min         575
# 1    auth1_cat1_1_all_before_1month_card_id_city_id...         593
# 165                         new_hist_installments_mean         618
# ..                                                 ...         ...
# 138                                     month_lag_mean        1444
# 124                            hist_weekofyear_nunique        1491
# 59   card_id_last_month_purchase_amount_ratio_each_...        1492
# 58   card_id_last_month_purchase_amount_ratio_each_...        1492
# 49   card_id_card_id_month_lag_purchase_amount_mean...        1501
# 98                               hist_installments_sum        1505
# 143                        new_hist_card_id_month_mean        1544
# 25   auth1_last_1month_card_id_merchant_category_id...        1550
# 14   auth1_cat1_last_month_card_id_purchase_amount_sum        1559
# 8    auth1_cat1_1_last_1month_card_id_purchase_amou...        1561
# 108                                 hist_month_lag_var        1590
# 15   auth1_cat1_last_month_card_id_purchase_amount_...        1603
# 119                         hist_purchase_date_uptonow        1632
# 151                            new_hist_category_1_sum        1633
# 180                       new_hist_purchase_amount_min        1633
# 80                                hist_category_1_mean        1653
# 136                                   month_diff_ratio        1673
# 27   auth1_last_1month_card_id_merchant_id_nunique_...        1703
# 5    auth1_cat1_1_last_1month_card_id_purchase_amou...        1721
# 11   auth1_cat1_last_month_card_id_purchase_amount_...        1776
# 46   card_id_card_id_month_lag_purchase_amount_coun...        1786
# 109                           hist_purchase_amount_max        1804
# 41                            auth_1_card_id_month_std        1815
# 68                          diff_new_hist_date_min_max        1833
# 23    auth1_last_1month_card_id_installments_sum_ratio        1834
# 30                           auth_0_card_id_month_mean        1838
# 51   card_id_card_id_month_lag_subsector_id_nunique...        1875
# 12   auth1_cat1_last_month_card_id_purchase_amount_...        1929
# 19   auth1_last_1month_card_id_installments_count_r...        1930
# 104                                hist_month_diff_var        1943
# 115                            hist_purchase_date_diff        1957
# 6    auth1_cat1_1_last_1month_card_id_purchase_amou...        1960
# 83                                 hist_dayofweek_mean        1993
# 111                           hist_purchase_amount_min        2027
# 184                        new_hist_purchase_date_diff        2071
# 63                                     category_1_mean        2084
# 117                             hist_purchase_date_min        2108
# 161                                 new_hist_hour_mean        2117
# 175                            new_hist_month_lag_mean        2118
# 21   auth1_last_1month_card_id_installments_mean_ratio        2137
# 149                           new_hist_category_1_mean        2148
# 92                                      hist_hour_mean        2171
# 183                     new_hist_purchase_date_average        2225
# 191                            new_hist_weekofyear_min        2271
# 110                          hist_purchase_amount_mean        2324
# 188                     new_hist_purchase_date_uptonow        2369
# 55                                   card_id_cnt_ratio        2404
# 116                             hist_purchase_date_max        2410
# 13   auth1_cat1_last_month_card_id_purchase_amount_...        2419
# 182                       new_hist_purchase_amount_var        2468
# 189                            new_hist_weekofyear_max        2493
# 33                            auth_0_card_id_month_std        2553
# 131                   last_month_purchase_amount_ratio        2625
# 186                         new_hist_purchase_date_min        2751
# 50   card_id_card_id_month_lag_purchase_amount_mean...        2843
# 81                                 hist_category_1_sum        2900
# 190                           new_hist_weekofyear_mean        3429
# 77                           hist_authorized_flag_mean        3450
# 40                        auth_1_card_id_month_nunique        3468
# 185                         new_hist_purchase_date_max        3535
# 70                          elapsed_time_outliers_mean        3742
# 179                      new_hist_purchase_amount_mean        3814
# 102                               hist_month_diff_mean        3895
# 178                       new_hist_purchase_amount_max        5674
# 67                          diff_new_hist_date_max_max        6408
#
# [205 rows x 2 columns]

# %%
sub_df = pd.DataFrame({"card_id":test_df["card_id"].values})
sub_df['target'] = predictions
#sub_df.loc[sub_df['target']<-9,'target'] = -33.21928095
sub_df.to_csv("output/submission_{}.csv".format(filename), index=False)

# %% [markdown]
# # Post Processing

# %% [markdown]
# ### without Outlier

# %%
train_df = all_df.loc[all_df['target'].notnull()]
test_df = all_df.loc[all_df['target'].isnull()]
train_df = train_df.loc[train_df['target']>-30]

train_columns = [c for c in train_df.columns if c not in ['card_id', 'first_active_month','target','outliers',
                                                          'auth1_cat1_last_month_card_id_purchase_amount_mean',
 'auth1_cat1_last_month_card_id_purchase_amount_count',
 'auth1_cat1_last_month_card_id_purchase_amount_sum',
 'auth1_cat1_last_month_card_id_purchase_amount_mean_ratio',
 'auth1_cat1_last_month_card_id_purchase_amount_count_ratio',
 'auth1_cat1_last_month_card_id_purchase_amount_sum_ratio',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_mean',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_count',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_sum',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_mean_ratio',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_count_ratio',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_sum_ratio','auth1_cat1_1_all_before_1month_card_id_merchant_id_nunique',
 'auth1_last_1month_card_id_merchant_id_nunique',
 'auth1_last_1month_card_id_merchant_id_nunique_ratio',
                                                         
                                                         ]]
train_columns
# Out:
# ['feature_1',
#  'feature_2',
#  'feature_3',
#  'card_id_card_id_month_lag_purchase_amount_count_sum',
#  'card_id_card_id_month_lag_purchase_amount_count_mean',
#  'card_id_card_id_month_lag_purchase_amount_count_std',
#  'card_id_card_id_month_lag_purchase_amount_mean_sum',
#  'card_id_card_id_month_lag_purchase_amount_mean_mean',
#  'card_id_card_id_month_lag_purchase_amount_mean_std',
#  'auth_0_card_id_month_nunique',
#  'auth_0_card_id_month_max',
#  'auth_0_card_id_month_min',
#  'auth_0_card_id_month_mean',
#  'auth_0_card_id_month_std',
#  'auth_1_card_id_month_nunique',
#  'auth_1_card_id_month_max',
#  'auth_1_card_id_month_min',
#  'auth_1_card_id_month_mean',
#  'auth_1_card_id_month_std',
#  'new_hist_card_id_month_nunique',
#  'new_hist_card_id_month_max',
#  'new_hist_card_id_month_min',
#  'new_hist_card_id_month_mean',
#  'card_id_merchant_id_nunique',
#  'auth_0_card_id_merchant_category_id_nunique',
#  'auth_1_card_id_merchant_category_id_nunique',
#  'auth_0_card_id_subsector_id_nunique',
#  'auth_1_card_id_subsector_id_nunique',
#  'auth_0_card_id_state_id_nunique',
#  'auth_1_card_id_state_id_nunique',
#  'card_id_city_id_nunique',
#  'new_hist_card_id_merchant_category_id_nunique',
#  'new_hist_card_id_subsector_id_nunique',
#  'new_hist_card_id_state_id_nunique',
#  'hist_hour_nunique',
#  'hist_hour_mean',
#  'hist_hour_min',
#  'hist_hour_max',
#  'hist_weekofyear_nunique',
#  'hist_weekofyear_mean',
#  'hist_weekofyear_min',
#  'hist_weekofyear_max',
#  'hist_dayofweek_nunique',
#  'hist_dayofweek_mean',
#  'hist_dayofweek_min',
#  'hist_dayofweek_max',
#  'hist_year_nunique',
#  'hist_year_mean',
#  'hist_purchase_amount_sum',
#  'hist_purchase_amount_max',
#  'hist_purchase_amount_min',
#  'hist_purchase_amount_mean',
#  'hist_purchase_amount_var',
#  'hist_installments_sum',
#  'hist_installments_max',
#  'hist_installments_min',
#  'hist_installments_mean',
#  'hist_installments_var',
#  'hist_purchase_date_max',
#  'hist_purchase_date_min',
#  'hist_month_lag_max',
#  'hist_month_lag_min',
#  'hist_month_lag_mean',
#  'hist_month_lag_var',
#  'hist_month_diff_mean',
#  'hist_month_diff_max',
#  'hist_month_diff_min',
#  'hist_month_diff_var',
#  'hist_category_1_sum',
#  'hist_category_1_mean',
#  'hist_authorized_flag_sum',
#  'hist_authorized_flag_mean',
#  'hist_card_id_size',
#  'hist_reference_date_median',
#  'hist_purchase_date_diff',
#  'hist_purchase_date_average',
#  'hist_purchase_date_uptonow',
#  'hist_purchase_date_uptomin',
#  'new_hist_hour_nunique',
#  'new_hist_hour_mean',
#  'new_hist_hour_min',
#  'new_hist_hour_max',
#  'new_hist_weekofyear_nunique',
#  'new_hist_weekofyear_mean',
#  'new_hist_weekofyear_min',
#  'new_hist_weekofyear_max',
#  'new_hist_dayofweek_nunique',
#  'new_hist_dayofweek_mean',
#  'new_hist_dayofweek_min',
#  'new_hist_dayofweek_max',
#  'new_hist_year_nunique',
#  'new_hist_year_mean',
#  'new_hist_purchase_amount_sum',
#  'new_hist_purchase_amount_max',
#  'new_hist_purchase_amount_min',
#  'new_hist_purchase_amount_mean',
#  'new_hist_purchase_amount_var',
#  'new_hist_installments_sum',
#  'new_hist_installments_max',
#  'new_hist_installments_min',
#  'new_hist_installments_mean',
#  'new_hist_installments_var',
#  'new_hist_purchase_date_max',
#  'new_hist_purchase_date_min',
#  'new_hist_month_lag_max',
#  'new_hist_month_lag_min',
#  'new_hist_month_lag_mean',
#  'new_hist_month_lag_var',
#  'new_hist_month_diff_mean',
#  'new_hist_month_diff_max',
#  'new_hist_month_diff_min',
#  'new_hist_month_diff_var',
#  'new_hist_category_1_sum',
#  'new_hist_category_1_mean',
#  'new_hist_category_1_min',
#  'new_hist_card_id_size',
#  'new_hist_purchase_date_diff',
#  'new_hist_purchase_date_average',
#  'new_hist_purchase_date_uptonow',
#  'new_hist_purchase_date_uptomin',
#  'dayofweek',
#  'weekofyear',
#  'dayofyear',
#  'quarter',
#  'month',
#  'elapsed_time',
#  'hist_first_buy',
#  'hist_last_buy',
#  'new_hist_first_buy',
#  'new_hist_last_buy',
#  'hist_diff_reference_date_first',
#  'hist_diff_reference_date_last',
#  'new_hist_diff_reference_date_first',
#  'new_hist_diff_reference_date_last',
#  'hist_diff_first_last',
#  'diff_new_hist_date_min_max',
#  'diff_new_hist_date_max_max',
#  'hist_flag_ratio',
#  'card_id_total',
#  'card_id_cnt_ratio',
#  'purchase_amount_total',
#  'purchase_amount_mean',
#  'purchase_amount_max',
#  'purchase_amount_min',
#  'purchase_amount_ratio',
#  'month_diff_mean',
#  'month_diff_ratio',
#  'month_lag_mean',
#  'month_lag_max',
#  'month_lag_min',
#  'category_1_mean',
#  'installments_total',
#  'installments_mean',
#  'installments_max',
#  'installments_ratio',
#  'price_total',
#  'price_mean',
#  'price_max',
#  'new_CLV',
#  'hist_CLV',
#  'CLV_ratio',
#  'new_hist_flag_ratio',
#  'feature123',
#  'card_id_card_id_month_lag_subsector_id_nunique_sum',
#  'card_id_card_id_month_lag_subsector_id_nunique_mean',
#  'card_id_card_id_month_lag_subsector_id_nunique_std',
#  'mode_card_id_subsector_id_nunique',
#  'mode_card_id_merchant_category_id_nunique',
#  'feature123_frequency_encoding',
#  'before_firstactive_purchase_ratio',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_min',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_max',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_sum',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_mean',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_std',
#  'last_month_purchase_amount_ratio']

# %%
train = train_df.copy()
target = train['target']
del train['target']

# %%
param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.015,
         "min_child_samples": 20,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "metric": 'rmse',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 24,
         "seed": 6}

#prepare fit model with cross-validation
np.random.seed(2019)

folds = KFold(n_splits=9, shuffle=True, random_state=4950)
oof = np.zeros(len(train))
predictions = np.zeros(len(test_df))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train)):
    strLog = "fold {}".format(fold_+1)
    print(strLog)
    trn_data = lgb.Dataset(train.iloc[trn_idx][train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 100)
    oof[val_idx] = clf.predict(train.iloc[val_idx][train_columns], num_iteration=clf.best_iteration)
    
    #feature importance
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    #predictions
    predictions += clf.predict(test_df[train_columns], num_iteration=clf.best_iteration) / folds.n_splits
    
cv_score = np.sqrt(mean_squared_error(oof, target))
print(cv_score)
withoutoutlier_predictions = predictions.copy()
# Out:
# fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.58747	valid_1's rmse: 1.57946
# [200]	training's rmse: 1.55982	valid_1's rmse: 1.55655
# [300]	training's rmse: 1.54578	valid_1's rmse: 1.54784
# [400]	training's rmse: 1.53583	valid_1's rmse: 1.54383
# [500]	training's rmse: 1.52779	valid_1's rmse: 1.54162
# [600]	training's rmse: 1.52081	valid_1's rmse: 1.5407
# [700]	training's rmse: 1.51436	valid_1's rmse: 1.54005
# [800]	training's rmse: 1.50839	valid_1's rmse: 1.53953
# [900]	training's rmse: 1.50271	valid_1's rmse: 1.53918
# [1000]	training's rmse: 1.49713	valid_1's rmse: 1.53891
# [1100]	training's rmse: 1.49178	valid_1's rmse: 1.53864
# [1200]	training's rmse: 1.48668	valid_1's rmse: 1.53847
# [1300]	training's rmse: 1.48163	valid_1's rmse: 1.5383
# [1400]	training's rmse: 1.47671	valid_1's rmse: 1.5383
# Early stopping, best iteration is:
# [1374]	training's rmse: 1.47802	valid_1's rmse: 1.53816
# fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.58508	valid_1's rmse: 1.59742
# [200]	training's rmse: 1.5572	valid_1's rmse: 1.57679
# [300]	training's rmse: 1.54318	valid_1's rmse: 1.56934
# [400]	training's rmse: 1.5333	valid_1's rmse: 1.56546
# [500]	training's rmse: 1.52534	valid_1's rmse: 1.56343
# [600]	training's rmse: 1.51851	valid_1's rmse: 1.56246
# [700]	training's rmse: 1.5122	valid_1's rmse: 1.56192
# [800]	training's rmse: 1.50624	valid_1's rmse: 1.56137
# [900]	training's rmse: 1.50059	valid_1's rmse: 1.56093
# [1000]	training's rmse: 1.49517	valid_1's rmse: 1.56067
# [1100]	training's rmse: 1.4899	valid_1's rmse: 1.56035
# [1200]	training's rmse: 1.48485	valid_1's rmse: 1.56013
# [1300]	training's rmse: 1.47986	valid_1's rmse: 1.55996
# Early stopping, best iteration is:
# [1281]	training's rmse: 1.48076	valid_1's rmse: 1.55989
# fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.5857	valid_1's rmse: 1.59093
# [200]	training's rmse: 1.55756	valid_1's rmse: 1.57209
# [300]	training's rmse: 1.54306	valid_1's rmse: 1.56599
# [400]	training's rmse: 1.53309	valid_1's rmse: 1.56333
# [500]	training's rmse: 1.525	valid_1's rmse: 1.56217
# [600]	training's rmse: 1.51802	valid_1's rmse: 1.56137
# [700]	training's rmse: 1.51169	valid_1's rmse: 1.56084
# [800]	training's rmse: 1.50581	valid_1's rmse: 1.56058
# [900]	training's rmse: 1.50023	valid_1's rmse: 1.56043
# [1000]	training's rmse: 1.49468	valid_1's rmse: 1.56025
# [1100]	training's rmse: 1.48928	valid_1's rmse: 1.56018
# [1200]	training's rmse: 1.48395	valid_1's rmse: 1.55997
# [1300]	training's rmse: 1.47904	valid_1's rmse: 1.56011
# Early stopping, best iteration is:
# [1211]	training's rmse: 1.48338	valid_1's rmse: 1.55993
# fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.58605	valid_1's rmse: 1.59017
# [200]	training's rmse: 1.55859	valid_1's rmse: 1.56745
# [300]	training's rmse: 1.54467	valid_1's rmse: 1.55893
# [400]	training's rmse: 1.53483	valid_1's rmse: 1.55486
# [500]	training's rmse: 1.52682	valid_1's rmse: 1.55298
# [600]	training's rmse: 1.5198	valid_1's rmse: 1.55165
# [700]	training's rmse: 1.51358	valid_1's rmse: 1.55077
# [800]	training's rmse: 1.50774	valid_1's rmse: 1.55025
# [900]	training's rmse: 1.50217	valid_1's rmse: 1.54983
# [1000]	training's rmse: 1.49679	valid_1's rmse: 1.54958
# [1100]	training's rmse: 1.49149	valid_1's rmse: 1.54941
# [1200]	training's rmse: 1.48634	valid_1's rmse: 1.54932
# [1300]	training's rmse: 1.48136	valid_1's rmse: 1.5489
# [1400]	training's rmse: 1.4765	valid_1's rmse: 1.54883
# [1500]	training's rmse: 1.47151	valid_1's rmse: 1.54872
# [1600]	training's rmse: 1.4667	valid_1's rmse: 1.5485
# [1700]	training's rmse: 1.46206	valid_1's rmse: 1.54832
# [1800]	training's rmse: 1.45747	valid_1's rmse: 1.54826
# [1900]	training's rmse: 1.45297	valid_1's rmse: 1.54817
# Early stopping, best iteration is:
# [1867]	training's rmse: 1.45445	valid_1's rmse: 1.54812
# fold 5
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.5875	valid_1's rmse: 1.57794
# [200]	training's rmse: 1.55948	valid_1's rmse: 1.55724
# [300]	training's rmse: 1.54546	valid_1's rmse: 1.55043
# [400]	training's rmse: 1.53547	valid_1's rmse: 1.5469
# [500]	training's rmse: 1.52741	valid_1's rmse: 1.54515
# [600]	training's rmse: 1.52048	valid_1's rmse: 1.54434
# [700]	training's rmse: 1.5142	valid_1's rmse: 1.54394
# [800]	training's rmse: 1.50819	valid_1's rmse: 1.54348
# [900]	training's rmse: 1.50257	valid_1's rmse: 1.54323
# [1000]	training's rmse: 1.49693	valid_1's rmse: 1.54294
# [1100]	training's rmse: 1.49155	valid_1's rmse: 1.54271
# [1200]	training's rmse: 1.48637	valid_1's rmse: 1.54256
# [1300]	training's rmse: 1.4814	valid_1's rmse: 1.54233
# [1400]	training's rmse: 1.4765	valid_1's rmse: 1.54218
# [1500]	training's rmse: 1.47157	valid_1's rmse: 1.54199
# [1600]	training's rmse: 1.46677	valid_1's rmse: 1.54185
# [1700]	training's rmse: 1.46201	valid_1's rmse: 1.54181
# [1800]	training's rmse: 1.45734	valid_1's rmse: 1.54172
# Early stopping, best iteration is:
# [1788]	training's rmse: 1.45791	valid_1's rmse: 1.54166
# fold 6
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.58341	valid_1's rmse: 1.61395
# [200]	training's rmse: 1.5559	valid_1's rmse: 1.59093
# [300]	training's rmse: 1.5418	valid_1's rmse: 1.58196
# [400]	training's rmse: 1.53181	valid_1's rmse: 1.57767
# [500]	training's rmse: 1.52384	valid_1's rmse: 1.57563
# [600]	training's rmse: 1.51686	valid_1's rmse: 1.57441
# [700]	training's rmse: 1.51061	valid_1's rmse: 1.5736
# [800]	training's rmse: 1.50468	valid_1's rmse: 1.57341
# [900]	training's rmse: 1.49892	valid_1's rmse: 1.57296
# [1000]	training's rmse: 1.49346	valid_1's rmse: 1.5727
# [1100]	training's rmse: 1.48825	valid_1's rmse: 1.57246
# [1200]	training's rmse: 1.48288	valid_1's rmse: 1.57232
# [1300]	training's rmse: 1.47788	valid_1's rmse: 1.57225
# [1400]	training's rmse: 1.473	valid_1's rmse: 1.57217
# Early stopping, best iteration is:
# [1352]	training's rmse: 1.47532	valid_1's rmse: 1.57205
# fold 7
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.58687	valid_1's rmse: 1.58377
# [200]	training's rmse: 1.55905	valid_1's rmse: 1.56193
# [300]	training's rmse: 1.54503	valid_1's rmse: 1.554
# [400]	training's rmse: 1.53499	valid_1's rmse: 1.55007
# [500]	training's rmse: 1.52704	valid_1's rmse: 1.54807
# [600]	training's rmse: 1.52012	valid_1's rmse: 1.54709
# [700]	training's rmse: 1.51383	valid_1's rmse: 1.54628
# [800]	training's rmse: 1.50766	valid_1's rmse: 1.54553
# [900]	training's rmse: 1.50211	valid_1's rmse: 1.54517
# [1000]	training's rmse: 1.49674	valid_1's rmse: 1.54486
# [1100]	training's rmse: 1.49142	valid_1's rmse: 1.54457
# [1200]	training's rmse: 1.48625	valid_1's rmse: 1.54427
# [1300]	training's rmse: 1.48111	valid_1's rmse: 1.54425
# [1400]	training's rmse: 1.47618	valid_1's rmse: 1.5441
# [1500]	training's rmse: 1.47138	valid_1's rmse: 1.54399
# [1600]	training's rmse: 1.46651	valid_1's rmse: 1.54393
# [1700]	training's rmse: 1.46182	valid_1's rmse: 1.54396
# Early stopping, best iteration is:
# [1667]	training's rmse: 1.46346	valid_1's rmse: 1.54388
# fold 8
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.58564	valid_1's rmse: 1.594
# [200]	training's rmse: 1.55816	valid_1's rmse: 1.57024
# [300]	training's rmse: 1.54413	valid_1's rmse: 1.5613
# [400]	training's rmse: 1.53429	valid_1's rmse: 1.55734
# [500]	training's rmse: 1.52622	valid_1's rmse: 1.5549
# [600]	training's rmse: 1.51933	valid_1's rmse: 1.55391
# [700]	training's rmse: 1.51306	valid_1's rmse: 1.5532
# [800]	training's rmse: 1.50724	valid_1's rmse: 1.55265
# [900]	training's rmse: 1.50154	valid_1's rmse: 1.55244
# [1000]	training's rmse: 1.4961	valid_1's rmse: 1.55231
# [1100]	training's rmse: 1.49082	valid_1's rmse: 1.5521
# [1200]	training's rmse: 1.48564	valid_1's rmse: 1.55213
# Early stopping, best iteration is:
# [1107]	training's rmse: 1.49042	valid_1's rmse: 1.55207
# fold 9
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 1.58456	valid_1's rmse: 1.60143
# [200]	training's rmse: 1.5568	valid_1's rmse: 1.58055
# [300]	training's rmse: 1.54268	valid_1's rmse: 1.57289
# [400]	training's rmse: 1.53281	valid_1's rmse: 1.56933
# [500]	training's rmse: 1.52474	valid_1's rmse: 1.56733
# [600]	training's rmse: 1.51779	valid_1's rmse: 1.56621
# [700]	training's rmse: 1.51141	valid_1's rmse: 1.56532
# [800]	training's rmse: 1.50542	valid_1's rmse: 1.56465
# [900]	training's rmse: 1.49963	valid_1's rmse: 1.56417
# [1000]	training's rmse: 1.49415	valid_1's rmse: 1.56389
# [1100]	training's rmse: 1.48876	valid_1's rmse: 1.56361
# [1200]	training's rmse: 1.48343	valid_1's rmse: 1.56339
# [1300]	training's rmse: 1.47847	valid_1's rmse: 1.56323
# [1400]	training's rmse: 1.47344	valid_1's rmse: 1.56308
# [1500]	training's rmse: 1.46867	valid_1's rmse: 1.56295
# [1600]	training's rmse: 1.46402	valid_1's rmse: 1.56291
# [1700]	training's rmse: 1.45929	valid_1's rmse: 1.56284
# [1800]	training's rmse: 1.45464	valid_1's rmse: 1.56282
# [1900]	training's rmse: 1.45015	valid_1's rmse: 1.5628
# Early stopping, best iteration is:
# [1842]	training's rmse: 1.45271	valid_1's rmse: 1.56272
# 1.5532016598043572

# %% [markdown]
# 1.5541206116854704
#
# ratio 추가
# 1.5536569114204828
#
# 1.5534561554350272
#
# 'card_id_last_month_purchase_amount_ratio_each_merchant_id_min',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_max',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_sum',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_mean',
#  'card_id_last_month_purchase_amount_ratio_each_merchant_id_std',
#  'last_month_purchase_amount_ratio'
#
# 1.5533589631217688
#
# 1.5532016598043572
#
# feature 8은 안좋아짐
# 1.554..

# %%
model_without_outliers = pd.DataFrame({"card_id":test_df["card_id"].values})
model_without_outliers["target"] = withoutoutlier_predictions

# %% [markdown]
# ### outlier

# %%
train_df = all_df.loc[all_df['target'].notnull()]
test_df = all_df.loc[all_df['target'].isnull()]
#train_df = train_df.loc[train_df['target']>-30]

train_df['outliers'] = 0
train_df.loc[train_df['target'] < -30, 'outliers'] = 1
train_df['outliers'].value_counts()

for f in ['feature_1','feature_2','feature_3']:
    order_label = train_df.groupby([f])['outliers'].mean()
    train_df[f] = train_df[f].map(order_label)
    test_df[f] = test_df[f].map(order_label)

group_df = groupby_helper(train_df,['dayofyear'], 'outliers',['mean'])
train_df = train_df.merge(group_df, on=['dayofyear'], how='left')
test_df = test_df.merge(group_df, on=['dayofyear'], how='left')

group_df = groupby_helper(train_df,['elapsed_time'], 'outliers',['mean'])
train_df = train_df.merge(group_df, on=['elapsed_time'], how='left')
test_df = test_df.merge(group_df, on=['elapsed_time'], how='left')

train_columns = [c for c in train_df.columns if c not in ['card_id', 'first_active_month','target','outliers','last_month_purchase_amount_ratio',
                                                         'card_id_last_month_purchase_amount_ratio_each_merchant_id_min',
 'card_id_last_month_purchase_amount_ratio_each_merchant_id_max',
 'card_id_last_month_purchase_amount_ratio_each_merchant_id_sum',
 'card_id_last_month_purchase_amount_ratio_each_merchant_id_mean',
 'card_id_last_month_purchase_amount_ratio_each_merchant_id_std', # 여기까지 삭제하는 것이 제일 좋음
                                                         'auth1_cat1_last_month_card_id_purchase_amount_mean',
 'auth1_cat1_last_month_card_id_purchase_amount_count',
 'auth1_cat1_last_month_card_id_purchase_amount_sum',
 'auth1_cat1_last_month_card_id_purchase_amount_mean_ratio',
 'auth1_cat1_last_month_card_id_purchase_amount_count_ratio',
 'auth1_cat1_last_month_card_id_purchase_amount_sum_ratio',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_mean',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_count',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_sum',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_mean_ratio',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_count_ratio',
 'auth1_cat1_1_last_1month_card_id_purchase_amount_sum_ratio',
 'auth1_cat1_1_all_before_1month_card_id_merchant_id_nunique',
 'auth1_last_1month_card_id_merchant_id_nunique',
 'auth1_last_1month_card_id_merchant_id_nunique_ratio']]
train_columns
# Out:
# ['dayofyear'] outliers ['mean']
# ['elapsed_time'] outliers ['mean']
# ['feature_1',
#  'feature_2',
#  'feature_3',
#  'card_id_card_id_month_lag_purchase_amount_count_sum',
#  'card_id_card_id_month_lag_purchase_amount_count_mean',
#  'card_id_card_id_month_lag_purchase_amount_count_std',
#  'card_id_card_id_month_lag_purchase_amount_mean_sum',
#  'card_id_card_id_month_lag_purchase_amount_mean_mean',
#  'card_id_card_id_month_lag_purchase_amount_mean_std',
#  'auth_0_card_id_month_nunique',
#  'auth_0_card_id_month_max',
#  'auth_0_card_id_month_min',
#  'auth_0_card_id_month_mean',
#  'auth_0_card_id_month_std',
#  'auth_1_card_id_month_nunique',
#  'auth_1_card_id_month_max',
#  'auth_1_card_id_month_min',
#  'auth_1_card_id_month_mean',
#  'auth_1_card_id_month_std',
#  'new_hist_card_id_month_nunique',
#  'new_hist_card_id_month_max',
#  'new_hist_card_id_month_min',
#  'new_hist_card_id_month_mean',
#  'card_id_merchant_id_nunique',
#  'auth_0_card_id_merchant_category_id_nunique',
#  'auth_1_card_id_merchant_category_id_nunique',
#  'auth_0_card_id_subsector_id_nunique',
#  'auth_1_card_id_subsector_id_nunique',
#  'auth_0_card_id_state_id_nunique',
#  'auth_1_card_id_state_id_nunique',
#  'card_id_city_id_nunique',
#  'new_hist_card_id_merchant_category_id_nunique',
#  'new_hist_card_id_subsector_id_nunique',
#  'new_hist_card_id_state_id_nunique',
#  'hist_hour_nunique',
#  'hist_hour_mean',
#  'hist_hour_min',
#  'hist_hour_max',
#  'hist_weekofyear_nunique',
#  'hist_weekofyear_mean',
#  'hist_weekofyear_min',
#  'hist_weekofyear_max',
#  'hist_dayofweek_nunique',
#  'hist_dayofweek_mean',
#  'hist_dayofweek_min',
#  'hist_dayofweek_max',
#  'hist_year_nunique',
#  'hist_year_mean',
#  'hist_purchase_amount_sum',
#  'hist_purchase_amount_max',
#  'hist_purchase_amount_min',
#  'hist_purchase_amount_mean',
#  'hist_purchase_amount_var',
#  'hist_installments_sum',
#  'hist_installments_max',
#  'hist_installments_min',
#  'hist_installments_mean',
#  'hist_installments_var',
#  'hist_purchase_date_max',
#  'hist_purchase_date_min',
#  'hist_month_lag_max',
#  'hist_month_lag_min',
#  'hist_month_lag_mean',
#  'hist_month_lag_var',
#  'hist_month_diff_mean',
#  'hist_month_diff_max',
#  'hist_month_diff_min',
#  'hist_month_diff_var',
#  'hist_category_1_sum',
#  'hist_category_1_mean',
#  'hist_authorized_flag_sum',
#  'hist_authorized_flag_mean',
#  'hist_card_id_size',
#  'hist_reference_date_median',
#  'hist_purchase_date_diff',
#  'hist_purchase_date_average',
#  'hist_purchase_date_uptonow',
#  'hist_purchase_date_uptomin',
#  'new_hist_hour_nunique',
#  'new_hist_hour_mean',
#  'new_hist_hour_min',
#  'new_hist_hour_max',
#  'new_hist_weekofyear_nunique',
#  'new_hist_weekofyear_mean',
#  'new_hist_weekofyear_min',
#  'new_hist_weekofyear_max',
#  'new_hist_dayofweek_nunique',
#  'new_hist_dayofweek_mean',
#  'new_hist_dayofweek_min',
#  'new_hist_dayofweek_max',
#  'new_hist_year_nunique',
#  'new_hist_year_mean',
#  'new_hist_purchase_amount_sum',
#  'new_hist_purchase_amount_max',
#  'new_hist_purchase_amount_min',
#  'new_hist_purchase_amount_mean',
#  'new_hist_purchase_amount_var',
#  'new_hist_installments_sum',
#  'new_hist_installments_max',
#  'new_hist_installments_min',
#  'new_hist_installments_mean',
#  'new_hist_installments_var',
#  'new_hist_purchase_date_max',
#  'new_hist_purchase_date_min',
#  'new_hist_month_lag_max',
#  'new_hist_month_lag_min',
#  'new_hist_month_lag_mean',
#  'new_hist_month_lag_var',
#  'new_hist_month_diff_mean',
#  'new_hist_month_diff_max',
#  'new_hist_month_diff_min',
#  'new_hist_month_diff_var',
#  'new_hist_category_1_sum',
#  'new_hist_category_1_mean',
#  'new_hist_category_1_min',
#  'new_hist_card_id_size',
#  'new_hist_purchase_date_diff',
#  'new_hist_purchase_date_average',
#  'new_hist_purchase_date_uptonow',
#  'new_hist_purchase_date_uptomin',
#  'dayofweek',
#  'weekofyear',
#  'dayofyear',
#  'quarter',
#  'month',
#  'elapsed_time',
#  'hist_first_buy',
#  'hist_last_buy',
#  'new_hist_first_buy',
#  'new_hist_last_buy',
#  'hist_diff_reference_date_first',
#  'hist_diff_reference_date_last',
#  'new_hist_diff_reference_date_first',
#  'new_hist_diff_reference_date_last',
#  'hist_diff_first_last',
#  'diff_new_hist_date_min_max',
#  'diff_new_hist_date_max_max',
#  'hist_flag_ratio',
#  'card_id_total',
#  'card_id_cnt_ratio',
#  'purchase_amount_total',
#  'purchase_amount_mean',
#  'purchase_amount_max',
#  'purchase_amount_min',
#  'purchase_amount_ratio',
#  'month_diff_mean',
#  'month_diff_ratio',
#  'month_lag_mean',
#  'month_lag_max',
#  'month_lag_min',
#  'category_1_mean',
#  'installments_total',
#  'installments_mean',
#  'installments_max',
#  'installments_ratio',
#  'price_total',
#  'price_mean',
#  'price_max',
#  'new_CLV',
#  'hist_CLV',
#  'CLV_ratio',
#  'new_hist_flag_ratio',
#  'feature123',
#  'card_id_card_id_month_lag_subsector_id_nunique_sum',
#  'card_id_card_id_month_lag_subsector_id_nunique_mean',
#  'card_id_card_id_month_lag_subsector_id_nunique_std',
#  'mode_card_id_subsector_id_nunique',
#  'mode_card_id_merchant_category_id_nunique',
#  'feature123_frequency_encoding',
#  'before_firstactive_purchase_ratio',
#  'auth1_cat1_last_month_card_id_purchase_amount_mean',
#  'auth1_cat1_last_month_card_id_purchase_amount_count',
#  'auth1_cat1_last_month_card_id_purchase_amount_sum',
#  'auth1_cat1_last_month_card_id_purchase_amount_mean_ratio',
#  'auth1_cat1_last_month_card_id_purchase_amount_count_ratio',
#  'auth1_cat1_last_month_card_id_purchase_amount_sum_ratio',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_mean',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_count',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_sum',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_mean_ratio',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_count_ratio',
#  'auth1_cat1_1_last_1month_card_id_purchase_amount_sum_ratio',
#  'auth1_cat1_1_all_before_1month_card_id_merchant_id_nunique',
#  'auth1_last_1month_card_id_merchant_id_nunique',
#  'auth1_last_1month_card_id_merchant_id_nunique_ratio',
#  'dayofyear_outliers_mean',
#  'elapsed_time_outliers_mean']

# %%
train = train_df.copy()
target = train['outliers']
del train['target']
del train['outliers']

# %%
gbdt_param = {'num_leaves': 31,
         'min_data_in_leaf': 30, 
         'objective':'binary',
         'max_depth': 5,
         'learning_rate': 0.01,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "metric": 'binary_logloss',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 24,
         "random_state": 6}

param = {'num_leaves': 128,
         'min_data_in_leaf': 50, 
         'objective':'binary',
         'max_depth': 9,
         'learning_rate': 0.1,
         "boosting": "rf",
         "feature_fraction": 0.6,
         "bagging_freq": 1,
         "bagging_fraction": 0.9 ,
         "metric": 'binary_logloss',
         "lambda_l1": 0.1,
         "verbosity": -1,
         "nthread": 24,
         "random_state": 6}

folds = KFold(n_splits=9, shuffle=True, random_state=4950)
oof = np.zeros(len(train))
predictions = np.zeros(len(test_df))

#start = time.time()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("fold {}".format(fold_+1))

    trn_data = lgb.Dataset(train.iloc[trn_idx][train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train.iloc[val_idx][train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)
    num_round = 10000
    clf = lgb.train(gbdt_param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(train.iloc[val_idx][train_columns], num_iteration=clf.best_iteration)
    
    predictions += clf.predict(test_df[train_columns], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.6f}".format(log_loss(target, oof)))
# Out:
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0445298	valid_1's binary_logloss: 0.0474313
# [200]	training's binary_logloss: 0.0411118	valid_1's binary_logloss: 0.0450948
# [300]	training's binary_logloss: 0.0391712	valid_1's binary_logloss: 0.0444177
# [400]	training's binary_logloss: 0.0377888	valid_1's binary_logloss: 0.0441654
# [500]	training's binary_logloss: 0.0365649	valid_1's binary_logloss: 0.0440653
# [600]	training's binary_logloss: 0.0354308	valid_1's binary_logloss: 0.0439706
# [700]	training's binary_logloss: 0.0343632	valid_1's binary_logloss: 0.0439558
# [800]	training's binary_logloss: 0.0333089	valid_1's binary_logloss: 0.0439396
# [900]	training's binary_logloss: 0.0324007	valid_1's binary_logloss: 0.0439879
# [1000]	training's binary_logloss: 0.0314276	valid_1's binary_logloss: 0.0440169
# Early stopping, best iteration is:
# [802]	training's binary_logloss: 0.0332753	valid_1's binary_logloss: 0.0439395
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0444789	valid_1's binary_logloss: 0.0464607
# [200]	training's binary_logloss: 0.0410678	valid_1's binary_logloss: 0.0446231
# [300]	training's binary_logloss: 0.0391044	valid_1's binary_logloss: 0.0441291
# [400]	training's binary_logloss: 0.0378198	valid_1's binary_logloss: 0.0439938
# [500]	training's binary_logloss: 0.0366508	valid_1's binary_logloss: 0.043968
# [600]	training's binary_logloss: 0.0355264	valid_1's binary_logloss: 0.0440309
# Early stopping, best iteration is:
# [441]	training's binary_logloss: 0.0373301	valid_1's binary_logloss: 0.0439414
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0441904	valid_1's binary_logloss: 0.0496668
# [200]	training's binary_logloss: 0.0408257	valid_1's binary_logloss: 0.0474336
# [300]	training's binary_logloss: 0.0389052	valid_1's binary_logloss: 0.046797
# [400]	training's binary_logloss: 0.0375984	valid_1's binary_logloss: 0.0465801
# [500]	training's binary_logloss: 0.0363717	valid_1's binary_logloss: 0.0464824
# [600]	training's binary_logloss: 0.0352201	valid_1's binary_logloss: 0.046413
# [700]	training's binary_logloss: 0.0341404	valid_1's binary_logloss: 0.0463595
# [800]	training's binary_logloss: 0.0331926	valid_1's binary_logloss: 0.0463456
# [900]	training's binary_logloss: 0.0323411	valid_1's binary_logloss: 0.0463311
# [1000]	training's binary_logloss: 0.0314433	valid_1's binary_logloss: 0.0462807
# [1100]	training's binary_logloss: 0.0306184	valid_1's binary_logloss: 0.0462882
# [1200]	training's binary_logloss: 0.0297769	valid_1's binary_logloss: 0.0462795
# Early stopping, best iteration is:
# [1018]	training's binary_logloss: 0.0312727	valid_1's binary_logloss: 0.0462579
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0444417	valid_1's binary_logloss: 0.0481989
# [200]	training's binary_logloss: 0.0410713	valid_1's binary_logloss: 0.0460779
# [300]	training's binary_logloss: 0.0390762	valid_1's binary_logloss: 0.045437
# [400]	training's binary_logloss: 0.0376563	valid_1's binary_logloss: 0.0451967
# [500]	training's binary_logloss: 0.0364764	valid_1's binary_logloss: 0.0450842
# [600]	training's binary_logloss: 0.0353996	valid_1's binary_logloss: 0.0449956
# [700]	training's binary_logloss: 0.0343409	valid_1's binary_logloss: 0.0449678
# [800]	training's binary_logloss: 0.0333719	valid_1's binary_logloss: 0.0449236
# [900]	training's binary_logloss: 0.0324658	valid_1's binary_logloss: 0.0449165
# [1000]	training's binary_logloss: 0.0315275	valid_1's binary_logloss: 0.0449283
# [1100]	training's binary_logloss: 0.0306626	valid_1's binary_logloss: 0.044945
# Early stopping, best iteration is:
# [912]	training's binary_logloss: 0.032352	valid_1's binary_logloss: 0.0448999
# fold 5
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0450013	valid_1's binary_logloss: 0.0435917
# [200]	training's binary_logloss: 0.0416052	valid_1's binary_logloss: 0.0414559
# [300]	training's binary_logloss: 0.0396156	valid_1's binary_logloss: 0.0408114
# [400]	training's binary_logloss: 0.0381925	valid_1's binary_logloss: 0.04059
# [500]	training's binary_logloss: 0.0369803	valid_1's binary_logloss: 0.0404964
# [600]	training's binary_logloss: 0.0357841	valid_1's binary_logloss: 0.0404472
# [700]	training's binary_logloss: 0.0346699	valid_1's binary_logloss: 0.0404803
# [800]	training's binary_logloss: 0.0336959	valid_1's binary_logloss: 0.0404907
# Early stopping, best iteration is:
# [611]	training's binary_logloss: 0.0356739	valid_1's binary_logloss: 0.040441
# fold 6
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.044703	valid_1's binary_logloss: 0.0457773
# [200]	training's binary_logloss: 0.0412793	valid_1's binary_logloss: 0.0440142
# [300]	training's binary_logloss: 0.0393037	valid_1's binary_logloss: 0.0434654
# [400]	training's binary_logloss: 0.0379304	valid_1's binary_logloss: 0.0432798
# [500]	training's binary_logloss: 0.0367485	valid_1's binary_logloss: 0.0431914
# [600]	training's binary_logloss: 0.0356666	valid_1's binary_logloss: 0.0432281
# [700]	training's binary_logloss: 0.0346338	valid_1's binary_logloss: 0.0432157
# Early stopping, best iteration is:
# [518]	training's binary_logloss: 0.0365213	valid_1's binary_logloss: 0.0431903
# fold 7
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.044524	valid_1's binary_logloss: 0.046788
# [200]	training's binary_logloss: 0.0411546	valid_1's binary_logloss: 0.0447927
# [300]	training's binary_logloss: 0.0391664	valid_1's binary_logloss: 0.0442666
# [400]	training's binary_logloss: 0.0377612	valid_1's binary_logloss: 0.0440258
# [500]	training's binary_logloss: 0.0365375	valid_1's binary_logloss: 0.0438962
# [600]	training's binary_logloss: 0.035331	valid_1's binary_logloss: 0.043866
# [700]	training's binary_logloss: 0.0342971	valid_1's binary_logloss: 0.0438359
# [800]	training's binary_logloss: 0.0333103	valid_1's binary_logloss: 0.0438555
# [900]	training's binary_logloss: 0.0323802	valid_1's binary_logloss: 0.0438527
# Early stopping, best iteration is:
# [711]	training's binary_logloss: 0.0341835	valid_1's binary_logloss: 0.0438286
# fold 8
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0447029	valid_1's binary_logloss: 0.0461819
# [200]	training's binary_logloss: 0.0412876	valid_1's binary_logloss: 0.0444483
# [300]	training's binary_logloss: 0.0393172	valid_1's binary_logloss: 0.0438924
# [400]	training's binary_logloss: 0.0379245	valid_1's binary_logloss: 0.0436873
# [500]	training's binary_logloss: 0.0366218	valid_1's binary_logloss: 0.0436007
# [600]	training's binary_logloss: 0.035451	valid_1's binary_logloss: 0.0435237
# [700]	training's binary_logloss: 0.0344024	valid_1's binary_logloss: 0.043488
# [800]	training's binary_logloss: 0.0333639	valid_1's binary_logloss: 0.0435112
# [900]	training's binary_logloss: 0.0324609	valid_1's binary_logloss: 0.0434756
# [1000]	training's binary_logloss: 0.031542	valid_1's binary_logloss: 0.0434408
# [1100]	training's binary_logloss: 0.030685	valid_1's binary_logloss: 0.0434142
# [1200]	training's binary_logloss: 0.0298685	valid_1's binary_logloss: 0.0434403
# Early stopping, best iteration is:
# [1047]	training's binary_logloss: 0.0311143	valid_1's binary_logloss: 0.043399
# fold 9
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.0449579	valid_1's binary_logloss: 0.0447278
# [200]	training's binary_logloss: 0.0415485	valid_1's binary_logloss: 0.0424785
# [300]	training's binary_logloss: 0.0395559	valid_1's binary_logloss: 0.0417494
# [400]	training's binary_logloss: 0.0381488	valid_1's binary_logloss: 0.0414519
# [500]	training's binary_logloss: 0.0370005	valid_1's binary_logloss: 0.0413296
# [600]	training's binary_logloss: 0.0358402	valid_1's binary_logloss: 0.0412729
# [700]	training's binary_logloss: 0.0348084	valid_1's binary_logloss: 0.041261
# [800]	training's binary_logloss: 0.0338536	valid_1's binary_logloss: 0.0412175
# [900]	training's binary_logloss: 0.0328795	valid_1's binary_logloss: 0.0412176
# Early stopping, best iteration is:
# [791]	training's binary_logloss: 0.0339311	valid_1's binary_logloss: 0.041213
# CV score: 0.043457

# %% [markdown]
# gdbt
# 0.043527
# CV score: 0.043523
#
# 20190214
# 0.043457
#
#
# rf
# CV score: 0.151194

# %%
df_outlier_prob = pd.DataFrame({"card_id":test_df["card_id"].values})
df_outlier_prob["target"] = predictions
df_outlier_prob.sort_values('target',ascending=False)
# Out:
#                 card_id    target
# 104991  C_ID_86ddafb51c  0.652219
# 32446   C_ID_ac114ef831  0.647792
# 20556   C_ID_aae50409e7  0.621640
# 37421   C_ID_366bf4ea4d  0.604123
# 5008    C_ID_be92f84f5c  0.594972
# 19114   C_ID_0be3fb41d2  0.594809
# 27384   C_ID_1a23d403c3  0.589626
# 54793   C_ID_761c27a0f2  0.567739
# 80840   C_ID_bced41d837  0.560360
# 88371   C_ID_26f775a95b  0.552046
# 25739   C_ID_99db441486  0.549926
# 27436   C_ID_493de71141  0.542186
# 119449  C_ID_3d40705001  0.540883
# 41756   C_ID_04214ceb9f  0.536442
# 108111  C_ID_b789a1772c  0.527671
# 17561   C_ID_f61641fbed  0.522769
# 63978   C_ID_4cf141070f  0.521019
# 6026    C_ID_91cc0c06ca  0.519285
# 27982   C_ID_e7f772dfc0  0.518820
# 5656    C_ID_126a403be9  0.515842
# 41138   C_ID_d706b6696a  0.509857
# 70804   C_ID_833aa2f7af  0.509041
# 85003   C_ID_00bf566320  0.508206
# 6595    C_ID_56b142e563  0.507680
# 120151  C_ID_3e3bb028d1  0.504976
# 33759   C_ID_1ac345139a  0.503495
# 77945   C_ID_6ab591cf62  0.497643
# 65911   C_ID_7d3b40444e  0.492926
# 78078   C_ID_922f9c5ea6  0.488916
# 48945   C_ID_afbfc01b49  0.487069
# 96354   C_ID_b237ce01cb  0.483207
# 107752  C_ID_0c22eb865e  0.481778
# 7750    C_ID_a74b12dcf8  0.477159
# 91624   C_ID_21a98a9c2e  0.473639
# 44491   C_ID_75519a6d74  0.467738
# 3398    C_ID_47a06004a5  0.467646
# 59178   C_ID_a4dfae60b0  0.464557
# 121274  C_ID_511216c4bf  0.462600
# 76013   C_ID_1afd4a6a1f  0.460629
# 42661   C_ID_e8865af4e4  0.460439
# 17531   C_ID_d2fb662751  0.459612
# 104274  C_ID_bf939aa4e9  0.458044
# 43454   C_ID_38cd39459c  0.456693
# 30531   C_ID_f643abe215  0.454904
# 45001   C_ID_f893e91649  0.454585
# 48373   C_ID_635d712d77  0.452651
# 82001   C_ID_ed2e21ada2  0.449783
# 77297   C_ID_b0c41ca140  0.446890
# 57547   C_ID_bc6884045c  0.446567
# 3709    C_ID_fe89c1890a  0.444471
# 121091  C_ID_7f06185ad1  0.443628
# 17720   C_ID_938dec7a1a  0.441204
# 35851   C_ID_5ee52cf9f6  0.440292
# 43215   C_ID_dc60219f6c  0.439888
# 68593   C_ID_b83c2f6ad4  0.439237
# 54886   C_ID_c7ca895f4a  0.438980
# 18363   C_ID_d2871ae781  0.438838
# 44180   C_ID_12b8c312ef  0.436005
# 82194   C_ID_5bc03fa634  0.434581
# 40613   C_ID_f337ea6293  0.430858
# 54870   C_ID_9a0e2fdc1d  0.429824
# 5707    C_ID_a8e502820c  0.427524
# 114106  C_ID_e54aeb08f7  0.426010
# 66362   C_ID_0bcfec9f5c  0.424468
# 38319   C_ID_dcb8dc61d6  0.423123
# ...                 ...       ...
# 84568   C_ID_e98f7707cf  0.000072
# 113261  C_ID_6733100d75  0.000072
# 27074   C_ID_3d662ba787  0.000072
# 111767  C_ID_33a8ca33cb  0.000071
# 104331  C_ID_cf77557d40  0.000071
# 709     C_ID_f909ce2ff1  0.000071
# 8411    C_ID_0298ed148f  0.000071
# 14139   C_ID_e6526efe1a  0.000071
# 1411    C_ID_dc2d16ea45  0.000071
# 13103   C_ID_9247fa4253  0.000071
# 35640   C_ID_08dee419de  0.000071
# 80492   C_ID_765b2fce24  0.000071
# 52373   C_ID_d70148931a  0.000071
# 57914   C_ID_d6682b4320  0.000071
# 21156   C_ID_178ad3f3bb  0.000071
# 33098   C_ID_356a58a831  0.000071
# 28659   C_ID_dc7f5a2d75  0.000071
# 84265   C_ID_15deb2071c  0.000071
# 102999  C_ID_171626f79b  0.000071
# 90012   C_ID_665db793b9  0.000071
# 41084   C_ID_26865148cd  0.000071
# 2879    C_ID_a39c3a8e27  0.000071
# 13780   C_ID_2feda71c61  0.000071
# 38701   C_ID_d610157fd4  0.000071
# 14669   C_ID_299dd820c5  0.000071
# 76564   C_ID_b102c4f958  0.000071
# 32741   C_ID_3f548b87b5  0.000071
# 97066   C_ID_0d0b14e74d  0.000071
# 35873   C_ID_792c417190  0.000071
# 77595   C_ID_e46489786e  0.000071
# 88689   C_ID_1f8e052c0b  0.000071
# 16084   C_ID_cf5510a796  0.000070
# 93300   C_ID_e329c36a23  0.000070
# 27181   C_ID_beff4f0d1b  0.000070
# 85050   C_ID_9e134e702b  0.000070
# 105144  C_ID_257aae90fe  0.000070
# 46560   C_ID_65b487e964  0.000070
# 54414   C_ID_c0fb871f87  0.000070
# 2385    C_ID_4f31074c18  0.000070
# 65227   C_ID_1add3eb7c6  0.000070
# 27106   C_ID_87d93c4cd6  0.000070
# 50647   C_ID_162a11dbdb  0.000070
# 34012   C_ID_516ec46dab  0.000069
# 26831   C_ID_26be2f693b  0.000069
# 7673    C_ID_dff5598236  0.000069
# 10917   C_ID_90e9521f03  0.000069
# 114101  C_ID_c3f688b390  0.000069
# 94147   C_ID_a0d1f6acbb  0.000069
# 103207  C_ID_2ed9b3275c  0.000069
# 99947   C_ID_76895ae730  0.000069
# 41811   C_ID_a90095a98a  0.000069
# 12089   C_ID_42de8486ba  0.000069
# 105201  C_ID_8e0fa01e0d  0.000069
# 109526  C_ID_6b134d0aed  0.000069
# 91615   C_ID_ddc0d55dd8  0.000069
# 42287   C_ID_c6d9e24b19  0.000069
# 30831   C_ID_3300cf0c82  0.000069
# 18094   C_ID_23c6d16bb6  0.000068
# 89158   C_ID_67c22ae220  0.000068
# 31933   C_ID_e8f6c462ed  0.000068
# 41958   C_ID_33dfc4e119  0.000068
# 38261   C_ID_b486330724  0.000067
# 31728   C_ID_9393a5a775  0.000067
# 22376   C_ID_96692208dd  0.000066
# 22917   C_ID_10bbf27f96  0.000065
#
# [123623 rows x 2 columns]

# %% [markdown]
# 현우님과 아웃라이어 모델 섞는 모델

# %%
hyeonwoo_outlier = pd.read_csv('hyeonwoo_outlier_cv0.043527.csv')
hyeonwoo_outlier.sort_values('target',ascending=False)
# Out:
#                 card_id    target
# 20556   C_ID_aae50409e7  0.612718
# 32446   C_ID_ac114ef831  0.578900
# 41138   C_ID_d706b6696a  0.572661
# 104991  C_ID_86ddafb51c  0.572087
# 114106  C_ID_e54aeb08f7  0.564345
# 119449  C_ID_3d40705001  0.557863
# 84189   C_ID_979347c28f  0.538942
# 5008    C_ID_be92f84f5c  0.537628
# 96354   C_ID_b237ce01cb  0.525527
# 77945   C_ID_6ab591cf62  0.510256
# 76013   C_ID_1afd4a6a1f  0.504936
# 27436   C_ID_493de71141  0.502945
# 19114   C_ID_0be3fb41d2  0.502277
# 81594   C_ID_3ba4759657  0.501824
# 79686   C_ID_aeedecc9ae  0.500278
# 116572  C_ID_f503a136f1  0.490661
# 88371   C_ID_26f775a95b  0.484957
# 78078   C_ID_922f9c5ea6  0.483510
# 111561  C_ID_da3b8bd9b2  0.481438
# 27982   C_ID_e7f772dfc0  0.479221
# 87901   C_ID_a4ca7a3f5d  0.478674
# 27314   C_ID_7f5f950342  0.466622
# 17561   C_ID_f61641fbed  0.460562
# 37421   C_ID_366bf4ea4d  0.458608
# 80840   C_ID_bced41d837  0.458556
# 65911   C_ID_7d3b40444e  0.458200
# 105577  C_ID_468f757dc6  0.456551
# 7750    C_ID_a74b12dcf8  0.455708
# 70804   C_ID_833aa2f7af  0.455092
# 2447    C_ID_0103766ffb  0.454042
# 40613   C_ID_f337ea6293  0.451625
# 69317   C_ID_52fe206a14  0.446544
# 69250   C_ID_82561a6c83  0.444389
# 27384   C_ID_1a23d403c3  0.442764
# 67890   C_ID_cde027fde7  0.442292
# 6026    C_ID_91cc0c06ca  0.440215
# 25568   C_ID_767923bdb9  0.438951
# 72846   C_ID_75c2316ae3  0.438554
# 63978   C_ID_4cf141070f  0.433461
# 17720   C_ID_938dec7a1a  0.431061
# 116264  C_ID_a475834914  0.428464
# 43763   C_ID_74dd007aec  0.426733
# 82194   C_ID_5bc03fa634  0.425115
# 43215   C_ID_dc60219f6c  0.423501
# 41519   C_ID_9cc91e5d00  0.422593
# 108111  C_ID_b789a1772c  0.422524
# 104274  C_ID_bf939aa4e9  0.420211
# 94668   C_ID_6e9a4a6008  0.420201
# 94759   C_ID_fc4463e3bd  0.418623
# 5656    C_ID_126a403be9  0.418327
# 41756   C_ID_04214ceb9f  0.417246
# 23168   C_ID_3804897561  0.414610
# 103851  C_ID_877b879853  0.413416
# 66343   C_ID_266c2f1192  0.413256
# 16074   C_ID_9c760806b5  0.411554
# 109705  C_ID_d596794318  0.410536
# 115609  C_ID_afbab1ba44  0.410132
# 111099  C_ID_601974ff16  0.408351
# 45119   C_ID_93c6231450  0.408116
# 121274  C_ID_511216c4bf  0.407303
# 74233   C_ID_b333d87776  0.405712
# 120151  C_ID_3e3bb028d1  0.404889
# 115682  C_ID_099d9774e2  0.404016
# 33759   C_ID_1ac345139a  0.403252
# 48945   C_ID_afbfc01b49  0.402469
# ...                 ...       ...
# 93253   C_ID_7ba91bd405  0.000096
# 32510   C_ID_713e3fc0ec  0.000096
# 72434   C_ID_45946d9a58  0.000096
# 10445   C_ID_ebbda424b9  0.000096
# 100149  C_ID_3a21f8feb4  0.000096
# 1564    C_ID_427abf4d26  0.000096
# 31933   C_ID_e8f6c462ed  0.000096
# 5325    C_ID_79999ca725  0.000096
# 70032   C_ID_2296b3d8cd  0.000096
# 47540   C_ID_23073c9099  0.000096
# 113357  C_ID_279fe1c968  0.000096
# 80108   C_ID_7310ba5f9a  0.000096
# 28418   C_ID_b476039b7f  0.000095
# 114113  C_ID_9cde604f0c  0.000095
# 44018   C_ID_a11ea8dff2  0.000095
# 97687   C_ID_3cd3091657  0.000095
# 41255   C_ID_41940ebef8  0.000095
# 108293  C_ID_fee8dc0937  0.000095
# 122638  C_ID_98e1b6a1db  0.000095
# 1411    C_ID_dc2d16ea45  0.000095
# 110965  C_ID_05c0a0278c  0.000095
# 20323   C_ID_8ec16d1173  0.000095
# 24420   C_ID_53fda320ea  0.000095
# 43442   C_ID_4b7c94dc0d  0.000095
# 8670    C_ID_6eef374980  0.000095
# 21156   C_ID_178ad3f3bb  0.000095
# 96076   C_ID_d2d833d49f  0.000094
# 40444   C_ID_52b886e7d5  0.000094
# 98386   C_ID_0c43a6666c  0.000094
# 102573  C_ID_cd4820d4d7  0.000094
# 69610   C_ID_b0ed6793d9  0.000094
# 109505  C_ID_fa5c039341  0.000094
# 17089   C_ID_1186dfa537  0.000094
# 112595  C_ID_ca8f68d5eb  0.000094
# 96921   C_ID_9cf51c10ca  0.000094
# 68699   C_ID_c17ca4dfc9  0.000094
# 82794   C_ID_2bfe25f196  0.000094
# 109697  C_ID_eff211ba6a  0.000093
# 61367   C_ID_5e0ae5a5d0  0.000093
# 104988  C_ID_cfc9b27207  0.000093
# 94940   C_ID_a27bd112ba  0.000093
# 12251   C_ID_6bdf1dfb1a  0.000093
# 79509   C_ID_61b0d286a5  0.000093
# 14669   C_ID_299dd820c5  0.000093
# 75521   C_ID_dc8ecee1a4  0.000093
# 11716   C_ID_a5e2ad104a  0.000093
# 27249   C_ID_96aa6102bf  0.000093
# 22917   C_ID_10bbf27f96  0.000092
# 88766   C_ID_cf2944a620  0.000092
# 118573  C_ID_fedb7195c4  0.000092
# 121496  C_ID_c11e9e139c  0.000092
# 32333   C_ID_bc2cef6d8e  0.000092
# 18094   C_ID_23c6d16bb6  0.000091
# 65897   C_ID_ad80c7d2bf  0.000091
# 122164  C_ID_559a559180  0.000091
# 19613   C_ID_a595ad7410  0.000091
# 70672   C_ID_2cceaa2c6e  0.000091
# 89668   C_ID_7fb61a5d62  0.000091
# 14139   C_ID_e6526efe1a  0.000091
# 3882    C_ID_3c8a425599  0.000090
# 41958   C_ID_33dfc4e119  0.000090
# 10869   C_ID_26eb077496  0.000089
# 114583  C_ID_6118921b97  0.000089
# 45386   C_ID_787fe619d4  0.000088
# 102999  C_ID_171626f79b  0.000087
#
# [123623 rows x 2 columns]

# %%
print("yeonmin", len(df_outlier_prob.loc[df_outlier_prob['target']>0.48,'card_id'].values))
print("hyeonwoo", len(hyeonwoo_outlier.loc[hyeonwoo_outlier['target']>0.48,'card_id'].values))
# Out:
# yeonmin 30
# hyeonwoo 19

# %%
top26_outlier = set(df_outlier_prob.loc[df_outlier_prob['target']>0.48,'card_id'].values).union(set(hyeonwoo_outlier.loc[hyeonwoo_outlier['target']>0.48,'card_id'].values))
len(top26_outlier)
# Out:
# 38

# %%
ym_top_30000 = set(df_outlier_prob.sort_values('target', ascending=False).head(30000)['card_id'].values)
hyeonwoo_top_30000 = set(hyeonwoo_outlier.sort_values('target', ascending=False).head(30000)['card_id'].values)
outlier_id_temp = pd.DataFrame(list(ym_top_30000.intersection(hyeonwoo_top_30000)),columns=['card_id'])
outlier_id_temp.shape
# Out:
# (26853, 1)

# %%
outlier_id = outlier_id_temp.copy()

# %% [markdown]
# single 671과 섞는 방법

# %%
outlier_id = pd.read_csv('best_lb_outlier_id.csv')
top20_outlier_id = pd.read_csv('best_lb_top20_outlier_id.csv')
#youhan_outlier = pd.read_csv('input/youhan_outlier.csv')
#outlier_id = pd.DataFrame(df_outlier_prob.sort_values('target',ascending=False).head(30000)['card_id'])

# %%
outlier_id_temp = pd.DataFrame(list(set(df_outlier_prob.loc[df_outlier_prob['target']>0.00203,'card_id'].values).intersection(set(outlier_id['card_id'].values))),columns=['card_id'])
outlier_id_temp.shape
# Out:
# (28095, 1)

# %%
outlier_id = outlier_id_temp.copy()

# %%
top26_outlier = list(set(df_outlier_prob.loc[df_outlier_prob['target']>0.5,'card_id'].values).union(set(top20_outlier_id['card_id'].values)))
len(top26_outlier)
# Out:
# 38

# %% [markdown]
# ### Best Submission

# %%
hyeonwoo_without_outlier = pd.read_csv('hyeonwoo_without_outlier_cv1.553025268039643.csv')
hyeonwoo_without_outlier.columns = ['card_id', 'h_target']

# %%
combine_hy_without_outlier = model_without_outliers.merge(hyeonwoo_without_outlier, on='card_id',how='left')
combine_hy_without_outlier['target'] = combine_hy_without_outlier['target']*0.5 + combine_hy_without_outlier['h_target']*0.5
del combine_hy_without_outlier['h_target']

# %%
hyeonwoo_best = pd.read_csv('output/v7_3.646642609714585.csv')
#hyeonwoo_best2 = pd.read_csv('output/FFM_MERCHANT.csv')
#print(hyeonwoo_best['target'].corr(hyeonwoo_best2['target']))
#hyeonwoo_best['target'] = hyeonwoo_best['target']*0.5 + hyeonwoo_best2['target']*0.5

# %%
my_best = pd.read_csv('output/submission_20190213_175946_cv3.639846.csv') # lb 3.678
#my_best2 = pd.read_csv('output/submission_20190213_175946_cv3.639846.csv') # lb 3.676
#print(my_best['target'].corr(my_best2['target']))
#my_best['target'] = my_best['target']*0.4 + my_best2['target']*0.6

# %% [markdown]
# 현우님 blend model lb 추정 3.678~679
# 내꺼 blend model lb 추정 3.675~3.676

# %%
hyeonwoo_best['target'].corr(my_best['target'])
# Out:
# 0.965890421664523

# %%
my_best['target'] = hyeonwoo_best['target']*0.55 + my_best['target']*0.45
best_submission = my_best.copy()
most_likely_liers = best_submission.merge(outlier_id,how='right')

# %%
only_without_outliers = combine_hy_without_outlier.loc[~combine_hy_without_outlier['card_id'].isin(most_likely_liers['card_id'].unique())]
submission = pd.concat([only_without_outliers, most_likely_liers])

# %%
filename = '{}'.format(datetime.now().strftime('%Y%m%d_%H%M%S'))
sub_df = pd.DataFrame({"card_id":test_df["card_id"].values})
sub_df = sub_df.merge(submission, on='card_id',how='left')
sub_df.loc[sub_df['card_id'].isin(top26_outlier),'target'] = -33.21928095
sub_df.to_csv("output/{}_submission_blend_blend.csv".format(filename), index=False)

# %%
sub_df.shape
# Out:
# (123623, 2)

# %%
sub_df.loc[sub_df['target']<-30].shape
# Out:
# (38, 2)
